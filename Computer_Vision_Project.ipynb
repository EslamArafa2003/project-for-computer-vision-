# %%
from google.colab import drive
import os
from zipfile import ZipFile
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import pairwise_distances
from skimage import feature
import cv2
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras import layers, models
from torchvision import datasets, transforms
from keras import regularizers
from keras.utils import plot_model
import pandas as pd
import seaborn as sn
import skimage.io
import keras.backend as K
#from helper_functions import set_seeds

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation
from tensorflow.keras.models import Model, Sequential
from keras.applications.nasnet import NASNetLarge
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive
#import zipfile
drive.mount('/content/drive')
# !unzip /content/drive/MyDrive/fer2013.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: fer2013/train/fear/Training_40907405.jpg
#   inflating: fer2013/train/fear/Training_40931156.jpg
#   inflating: fer2013/train/fear/Training_40932157.jpg
#   inflating: fer2013/train/fear/Training_40950329.jpg
#   inflating: fer2013/train/fear/Training_40974454.jpg
#   inflating: fer2013/train/fear/Training_40978078.jpg
#   inflating: fer2013/train/fear/Training_41005823.jpg
#   inflating: fer2013/train/fear/Training_41011618.jpg
#   inflating: fer2013/train/fear/Training_41052937.jpg
#   inflating: fer2013/train/fear/Training_41060596.jpg
#   inflating: fer2013/train/fear/Training_41083563.jpg
#   inflating: fer2013/train/fear/Training_41096941.jpg
#   inflating: fer2013/train/fear/Training_41101260.jpg
#   inflating: fer2013/train/fear/Training_41127415.jpg
#   inflating: fer2013/train/fear/Training_41136018.jpg
#   inflating: fer2013/train/fear/Training_41155688.jpg
#   inflating: fer2013/train/fear/Training_41182158.jpg
#   inflating: fer2013/train/fear/Training_41201040.jpg
#   inflating: fer2013/train/fear/Training_41216040.jpg
#   inflating: fer2013/train/fear/Training_41222416.jpg
#   inflating: fer2013/train/fear/Training_41233813.jpg
#   inflating: fer2013/train/fear/Training_41285448.jpg
#   inflating: fer2013/train/fear/Training_41314009.jpg
#   inflating: fer2013/train/fear/Training_41329223.jpg
#   inflating: fer2013/train/fear/Training_41330709.jpg
#   inflating: fer2013/train/fear/Training_41361960.jpg
#   inflating: fer2013/train/fear/Training_41379949.jpg
#   inflating: fer2013/train/fear/Training_41431542.jpg
#   inflating: fer2013/train/fear/Training_41454815.jpg
#   inflating: fer2013/train/fear/Training_41514601.jpg
#   inflating: fer2013/train/fear/Training_41548706.jpg
#   inflating: fer2013/train/fear/Training_41564249.jpg
#   inflating: fer2013/train/fear/Training_41571191.jpg
#   inflating: fer2013/train/fear/Training_41623616.jpg
#   inflating: fer2013/train/fear/Training_41627781.jpg
#   inflating: fer2013/train/fear/Training_41655166.jpg
#   inflating: fer2013/train/fear/Training_41669141.jpg
#   inflating: fer2013/train/fear/Training_41674916.jpg
#   inflating: fer2013/train/fear/Training_41682897.jpg
#   inflating: fer2013/train/fear/Training_41694221.jpg
#   inflating: fer2013/train/fear/Training_41718786.jpg
#   inflating: fer2013/train/fear/Training_41728519.jpg
#   inflating: fer2013/train/fear/Training_41730846.jpg
#   inflating: fer2013/train/fear/Training_41761159.jpg
#   inflating: fer2013/train/fear/Training_41788244.jpg
#   inflating: fer2013/train/fear/Training_41788550.jpg
#   inflating: fer2013/train/fear/Training_41831872.jpg
#   inflating: fer2013/train/fear/Training_41842862.jpg
#   inflating: fer2013/train/fear/Training_41848033.jpg
#   inflating: fer2013/train/fear/Training_41907508.jpg
#   inflating: fer2013/train/fear/Training_42024931.jpg
#   inflating: fer2013/train/fear/Training_42030519.jpg
#   inflating: fer2013/train/fear/Training_42037605.jpg
#   inflating: fer2013/train/fear/Training_42039488.jpg
#   inflating: fer2013/train/fear/Training_42042445.jpg
#   inflating: fer2013/train/fear/Training_42054202.jpg
#   inflating: fer2013/train/fear/Training_42080038.jpg
#   inflating: fer2013/train/fear/Training_42117120.jpg
#   inflating: fer2013/train/fear/Training_42181380.jpg
#   inflating: fer2013/train/fear/Training_42198912.jpg
#   inflating: fer2013/train/fear/Training_42208106.jpg
#   inflating: fer2013/train/fear/Training_42225771.jpg
#   inflating: fer2013/train/fear/Training_42262556.jpg
#   inflating: fer2013/train/fear/Training_42295808.jpg
#   inflating: fer2013/train/fear/Training_42299700.jpg
#   inflating: fer2013/train/fear/Training_42312801.jpg
#   inflating: fer2013/train/fear/Training_42322310.jpg
#   inflating: fer2013/train/fear/Training_42334589.jpg
#   inflating: fer2013/train/fear/Training_42339464.jpg
#   inflating: fer2013/train/fear/Training_42347407.jpg
#   inflating: fer2013/train/fear/Training_42376541.jpg
#   inflating: fer2013/train/fear/Training_42399713.jpg
#   inflating: fer2013/train/fear/Training_42465540.jpg
#   inflating: fer2013/train/fear/Training_42473007.jpg
#   inflating: fer2013/train/fear/Training_42504090.jpg
#   inflating: fer2013/train/fear/Training_42504871.jpg
#   inflating: fer2013/train/fear/Training_42531124.jpg
#   inflating: fer2013/train/fear/Training_42536701.jpg
#   inflating: fer2013/train/fear/Training_42554910.jpg
#   inflating: fer2013/train/fear/Training_42558552.jpg
#   inflating: fer2013/train/fear/Training_42593953.jpg
#   inflating: fer2013/train/fear/Training_42622027.jpg
#   inflating: fer2013/train/fear/Training_42660486.jpg
#   inflating: fer2013/train/fear/Training_42699416.jpg
#   inflating: fer2013/train/fear/Training_42747938.jpg
#   inflating: fer2013/train/fear/Training_42761363.jpg
#   inflating: fer2013/train/fear/Training_42781717.jpg
#   inflating: fer2013/train/fear/Training_42891366.jpg
#   inflating: fer2013/train/fear/Training_42893074.jpg
#   inflating: fer2013/train/fear/Training_42911068.jpg
#   inflating: fer2013/train/fear/Training_42935360.jpg
#   inflating: fer2013/train/fear/Training_42936686.jpg
#   inflating: fer2013/train/fear/Training_42945531.jpg
#   inflating: fer2013/train/fear/Training_42955258.jpg
#   inflating: fer2013/train/fear/Training_42975762.jpg
#   inflating: fer2013/train/fear/Training_43001072.jpg
#   inflating: fer2013/train/fear/Training_43015443.jpg
#   inflating: fer2013/train/fear/Training_43025256.jpg
#   inflating: fer2013/train/fear/Training_43058403.jpg
#   inflating: fer2013/train/fear/Training_43101242.jpg
#   inflating: fer2013/train/fear/Training_43101704.jpg
#   inflating: fer2013/train/fear/Training_51126382.jpg
#   inflating: fer2013/train/fear/Training_51209873.jpg
#   inflating: fer2013/train/fear/Training_51219003.jpg
#   inflating: fer2013/train/fear/Training_51259144.jpg
#   inflating: fer2013/train/fear/Training_51288323.jpg
#   inflating: fer2013/train/fear/Training_51304819.jpg
#   inflating: fer2013/train/fear/Training_51345259.jpg
#   inflating: fer2013/train/fear/Training_51347292.jpg
#   inflating: fer2013/train/fear/Training_51359688.jpg
#   inflating: fer2013/train/fear/Training_51424706.jpg
#   inflating: fer2013/train/fear/Training_51454604.jpg
#   inflating: fer2013/train/fear/Training_51455718.jpg
#   inflating: fer2013/train/fear/Training_51469887.jpg
#   inflating: fer2013/train/fear/Training_51486598.jpg
#   inflating: fer2013/train/fear/Training_51487186.jpg
#   inflating: fer2013/train/fear/Training_51522398.jpg
#   inflating: fer2013/train/fear/Training_51558303.jpg
#   inflating: fer2013/train/fear/Training_51589811.jpg
#   inflating: fer2013/train/fear/Training_51666410.jpg
#   inflating: fer2013/train/fear/Training_51678977.jpg
#   inflating: fer2013/train/fear/Training_51731782.jpg
#   inflating: fer2013/train/fear/Training_51735828.jpg
#   inflating: fer2013/train/fear/Training_51821307.jpg
#   inflating: fer2013/train/fear/Training_51829984.jpg
#   inflating: fer2013/train/fear/Training_51837573.jpg
#   inflating: fer2013/train/fear/Training_51868993.jpg
#   inflating: fer2013/train/fear/Training_51898156.jpg
#   inflating: fer2013/train/fear/Training_51906783.jpg
#   inflating: fer2013/train/fear/Training_51927091.jpg
#   inflating: fer2013/train/fear/Training_52000256.jpg
#   inflating: fer2013/train/fear/Training_52021600.jpg
#   inflating: fer2013/train/fear/Training_52053930.jpg
#   inflating: fer2013/train/fear/Training_52067174.jpg
#   inflating: fer2013/train/fear/Training_52070649.jpg
#   inflating: fer2013/train/fear/Training_52073662.jpg
#   inflating: fer2013/train/fear/Training_52132958.jpg
#   inflating: fer2013/train/fear/Training_52172993.jpg
#   inflating: fer2013/train/fear/Training_52199927.jpg
#   inflating: fer2013/train/fear/Training_52235688.jpg
#   inflating: fer2013/train/fear/Training_52317937.jpg
#   inflating: fer2013/train/fear/Training_52325190.jpg
#   inflating: fer2013/train/fear/Training_52331148.jpg
#   inflating: fer2013/train/fear/Training_52337440.jpg
#   inflating: fer2013/train/fear/Training_52397611.jpg
#   inflating: fer2013/train/fear/Training_52444932.jpg
#   inflating: fer2013/train/fear/Training_52470769.jpg
#   inflating: fer2013/train/fear/Training_52551879.jpg
#   inflating: fer2013/train/fear/Training_52552370.jpg
#   inflating: fer2013/train/fear/Training_52569023.jpg
#   inflating: fer2013/train/fear/Training_52587666.jpg
#   inflating: fer2013/train/fear/Training_52609889.jpg
#   inflating: fer2013/train/fear/Training_52623118.jpg
#   inflating: fer2013/train/fear/Training_52694550.jpg
#   inflating: fer2013/train/fear/Training_52706052.jpg
#   inflating: fer2013/train/fear/Training_52717878.jpg
#   inflating: fer2013/train/fear/Training_52769285.jpg
#   inflating: fer2013/train/fear/Training_52781503.jpg
#   inflating: fer2013/train/fear/Training_52792854.jpg
#   inflating: fer2013/train/fear/Training_52865320.jpg
#   inflating: fer2013/train/fear/Training_52868666.jpg
#   inflating: fer2013/train/fear/Training_52886042.jpg
#   inflating: fer2013/train/fear/Training_52933939.jpg
#   inflating: fer2013/train/fear/Training_53028968.jpg
#   inflating: fer2013/train/fear/Training_53053446.jpg
#   inflating: fer2013/train/fear/Training_53059587.jpg
#   inflating: fer2013/train/fear/Training_53063206.jpg
#   inflating: fer2013/train/fear/Training_53081821.jpg
#   inflating: fer2013/train/fear/Training_53110904.jpg
#   inflating: fer2013/train/fear/Training_53125866.jpg
#   inflating: fer2013/train/fear/Training_53131439.jpg
#   inflating: fer2013/train/fear/Training_53145551.jpg
#   inflating: fer2013/train/fear/Training_53176243.jpg
#   inflating: fer2013/train/fear/Training_53177826.jpg
#   inflating: fer2013/train/fear/Training_53192241.jpg
#   inflating: fer2013/train/fear/Training_53263108.jpg
#   inflating: fer2013/train/fear/Training_53283670.jpg
#   inflating: fer2013/train/fear/Training_53304511.jpg
#   inflating: fer2013/train/fear/Training_53311493.jpg
#   inflating: fer2013/train/fear/Training_53335695.jpg
#   inflating: fer2013/train/fear/Training_53337451.jpg
#   inflating: fer2013/train/fear/Training_53351251.jpg
#   inflating: fer2013/train/fear/Training_53356320.jpg
#   inflating: fer2013/train/fear/Training_53376951.jpg
#   inflating: fer2013/train/fear/Training_53396705.jpg
#   inflating: fer2013/train/fear/Training_53419711.jpg
#   inflating: fer2013/train/fear/Training_53424829.jpg
#   inflating: fer2013/train/fear/Training_53466351.jpg
#   inflating: fer2013/train/fear/Training_53472118.jpg
#   inflating: fer2013/train/fear/Training_53513185.jpg
#   inflating: fer2013/train/fear/Training_53535057.jpg
#   inflating: fer2013/train/fear/Training_53542121.jpg
#   inflating: fer2013/train/fear/Training_53542549.jpg
#   inflating: fer2013/train/fear/Training_53553139.jpg
#   inflating: fer2013/train/fear/Training_53559434.jpg
#   inflating: fer2013/train/fear/Training_53605910.jpg
#   inflating: fer2013/train/fear/Training_53631261.jpg
#   inflating: fer2013/train/fear/Training_53648467.jpg
#   inflating: fer2013/train/fear/Training_53651086.jpg
#   inflating: fer2013/train/fear/Training_53678309.jpg
#   inflating: fer2013/train/fear/Training_53708890.jpg
#   inflating: fer2013/train/fear/Training_53777140.jpg
#   inflating: fer2013/train/fear/Training_53835212.jpg
#   inflating: fer2013/train/fear/Training_53854073.jpg
#   inflating: fer2013/train/fear/Training_53890889.jpg
#   inflating: fer2013/train/fear/Training_53893619.jpg
#   inflating: fer2013/train/fear/Training_53919129.jpg
#   inflating: fer2013/train/fear/Training_53968107.jpg
#   inflating: fer2013/train/fear/Training_54024602.jpg
#   inflating: fer2013/train/fear/Training_54053151.jpg
#   inflating: fer2013/train/fear/Training_54071205.jpg
#   inflating: fer2013/train/fear/Training_54072906.jpg
#   inflating: fer2013/train/fear/Training_54074620.jpg
#   inflating: fer2013/train/fear/Training_54076125.jpg
#   inflating: fer2013/train/fear/Training_54098926.jpg
#   inflating: fer2013/train/fear/Training_54111102.jpg
#   inflating: fer2013/train/fear/Training_54146243.jpg
#   inflating: fer2013/train/fear/Training_54161950.jpg
#   inflating: fer2013/train/fear/Training_54167837.jpg
#   inflating: fer2013/train/fear/Training_54217503.jpg
#   inflating: fer2013/train/fear/Training_54322315.jpg
#   inflating: fer2013/train/fear/Training_64889337.jpg
#   inflating: fer2013/train/fear/Training_64905380.jpg
#   inflating: fer2013/train/fear/Training_64911295.jpg
#   inflating: fer2013/train/fear/Training_64921601.jpg
#   inflating: fer2013/train/fear/Training_64927151.jpg
#   inflating: fer2013/train/fear/Training_64950444.jpg
#   inflating: fer2013/train/fear/Training_64999870.jpg
#   inflating: fer2013/train/fear/Training_65055746.jpg
#   inflating: fer2013/train/fear/Training_65061192.jpg
#   inflating: fer2013/train/fear/Training_65087261.jpg
#   inflating: fer2013/train/fear/Training_65127450.jpg
#   inflating: fer2013/train/fear/Training_65136110.jpg
#   inflating: fer2013/train/fear/Training_65140524.jpg
#   inflating: fer2013/train/fear/Training_65191546.jpg
#   inflating: fer2013/train/fear/Training_65276779.jpg
#   inflating: fer2013/train/fear/Training_65306081.jpg
#   inflating: fer2013/train/fear/Training_65323777.jpg
#   inflating: fer2013/train/fear/Training_65333754.jpg
#   inflating: fer2013/train/fear/Training_65334911.jpg
#   inflating: fer2013/train/fear/Training_65347439.jpg
#   inflating: fer2013/train/fear/Training_65365689.jpg
#   inflating: fer2013/train/fear/Training_65366152.jpg
#   inflating: fer2013/train/fear/Training_65375648.jpg
#   inflating: fer2013/train/fear/Training_65376210.jpg
#   inflating: fer2013/train/fear/Training_65411489.jpg
#   inflating: fer2013/train/fear/Training_65465681.jpg
#   inflating: fer2013/train/fear/Training_65476433.jpg
#   inflating: fer2013/train/fear/Training_65494292.jpg
#   inflating: fer2013/train/fear/Training_65517430.jpg
#   inflating: fer2013/train/fear/Training_65561256.jpg
#   inflating: fer2013/train/fear/Training_65566794.jpg
#   inflating: fer2013/train/fear/Training_65590226.jpg
#   inflating: fer2013/train/fear/Training_65682151.jpg
#   inflating: fer2013/train/fear/Training_65711776.jpg
#   inflating: fer2013/train/fear/Training_65742283.jpg
#   inflating: fer2013/train/fear/Training_65752506.jpg
#   inflating: fer2013/train/fear/Training_65820611.jpg
#   inflating: fer2013/train/fear/Training_65828754.jpg
#   inflating: fer2013/train/fear/Training_65843496.jpg
#   inflating: fer2013/train/fear/Training_65873848.jpg
#   inflating: fer2013/train/fear/Training_65905937.jpg
#   inflating: fer2013/train/fear/Training_65918507.jpg
#   inflating: fer2013/train/fear/Training_65923733.jpg
#   inflating: fer2013/train/fear/Training_65930619.jpg
#   inflating: fer2013/train/fear/Training_65968117.jpg
#   inflating: fer2013/train/fear/Training_66039199.jpg
#   inflating: fer2013/train/fear/Training_66125783.jpg
#   inflating: fer2013/train/fear/Training_66141720.jpg
#   inflating: fer2013/train/fear/Training_66146107.jpg
#   inflating: fer2013/train/fear/Training_66152735.jpg
#   inflating: fer2013/train/fear/Training_66219669.jpg
#   inflating: fer2013/train/fear/Training_66229568.jpg
#   inflating: fer2013/train/fear/Training_66251173.jpg
#   inflating: fer2013/train/fear/Training_66264474.jpg
#   inflating: fer2013/train/fear/Training_66279343.jpg
#   inflating: fer2013/train/fear/Training_66291773.jpg
#   inflating: fer2013/train/fear/Training_66316008.jpg
#   inflating: fer2013/train/fear/Training_66355016.jpg
#   inflating: fer2013/train/fear/Training_66357584.jpg
#   inflating: fer2013/train/fear/Training_66358760.jpg
#   inflating: fer2013/train/fear/Training_66361270.jpg
#   inflating: fer2013/train/fear/Training_66372245.jpg
#   inflating: fer2013/train/fear/Training_66399541.jpg
#   inflating: fer2013/train/fear/Training_66412846.jpg
#   inflating: fer2013/train/fear/Training_66417775.jpg
#   inflating: fer2013/train/fear/Training_66512175.jpg
#   inflating: fer2013/train/fear/Training_66512433.jpg
#   inflating: fer2013/train/fear/Training_66537980.jpg
#   inflating: fer2013/train/fear/Training_66598933.jpg
#   inflating: fer2013/train/fear/Training_66633565.jpg
#   inflating: fer2013/train/fear/Training_66726285.jpg
#   inflating: fer2013/train/fear/Training_66772954.jpg
#   inflating: fer2013/train/fear/Training_66794307.jpg
#   inflating: fer2013/train/fear/Training_66800811.jpg
#   inflating: fer2013/train/fear/Training_66870066.jpg
#   inflating: fer2013/train/fear/Training_66880356.jpg
#   inflating: fer2013/train/fear/Training_66902094.jpg
#   inflating: fer2013/train/fear/Training_66928499.jpg
#   inflating: fer2013/train/fear/Training_66935602.jpg
#   inflating: fer2013/train/fear/Training_66993409.jpg
#   inflating: fer2013/train/fear/Training_67024159.jpg
#   inflating: fer2013/train/fear/Training_67036463.jpg
#   inflating: fer2013/train/fear/Training_67068753.jpg
#   inflating: fer2013/train/fear/Training_67094562.jpg
#   inflating: fer2013/train/fear/Training_67095352.jpg
#   inflating: fer2013/train/fear/Training_67109543.jpg
#   inflating: fer2013/train/fear/Training_67136718.jpg
#   inflating: fer2013/train/fear/Training_67152452.jpg
#   inflating: fer2013/train/fear/Training_67156583.jpg
#   inflating: fer2013/train/fear/Training_67192694.jpg
#   inflating: fer2013/train/fear/Training_67219690.jpg
#   inflating: fer2013/train/fear/Training_67224906.jpg
#   inflating: fer2013/train/fear/Training_67301901.jpg
#   inflating: fer2013/train/fear/Training_67308905.jpg
#   inflating: fer2013/train/fear/Training_67315251.jpg
#   inflating: fer2013/train/fear/Training_67370793.jpg
#   inflating: fer2013/train/fear/Training_67402580.jpg
#   inflating: fer2013/train/fear/Training_67411300.jpg
#   inflating: fer2013/train/fear/Training_67433032.jpg
#   inflating: fer2013/train/fear/Training_67436225.jpg
#   inflating: fer2013/train/fear/Training_67443640.jpg
#   inflating: fer2013/train/fear/Training_67475405.jpg
#   inflating: fer2013/train/fear/Training_67477638.jpg
#   inflating: fer2013/train/fear/Training_67492683.jpg
#   inflating: fer2013/train/fear/Training_67522276.jpg
#   inflating: fer2013/train/fear/Training_67555109.jpg
#   inflating: fer2013/train/fear/Training_67564066.jpg
#   inflating: fer2013/train/fear/Training_67568590.jpg
#   inflating: fer2013/train/fear/Training_67600403.jpg
#   inflating: fer2013/train/fear/Training_67622956.jpg
#   inflating: fer2013/train/fear/Training_67637966.jpg
#   inflating: fer2013/train/fear/Training_67655497.jpg
#   inflating: fer2013/train/fear/Training_67693174.jpg
#   inflating: fer2013/train/fear/Training_67838149.jpg
#   inflating: fer2013/train/fear/Training_67848767.jpg
#   inflating: fer2013/train/fear/Training_67872810.jpg
#   inflating: fer2013/train/fear/Training_67902170.jpg
#   inflating: fer2013/train/fear/Training_67906501.jpg
#   inflating: fer2013/train/fear/Training_67940332.jpg
#   inflating: fer2013/train/fear/Training_67990257.jpg
#   inflating: fer2013/train/fear/Training_68007328.jpg
#   inflating: fer2013/train/fear/Training_68008375.jpg
#   inflating: fer2013/train/fear/Training_68057622.jpg
#   inflating: fer2013/train/fear/Training_68065919.jpg
#   inflating: fer2013/train/fear/Training_68071992.jpg
#   inflating: fer2013/train/fear/Training_68099104.jpg
#   inflating: fer2013/train/fear/Training_68125686.jpg
#   inflating: fer2013/train/fear/Training_68140384.jpg
#   inflating: fer2013/train/fear/Training_68178773.jpg
#   inflating: fer2013/train/fear/Training_68222777.jpg
#   inflating: fer2013/train/fear/Training_68223904.jpg
#   inflating: fer2013/train/fear/Training_68270314.jpg
#   inflating: fer2013/train/fear/Training_68279733.jpg
#   inflating: fer2013/train/fear/Training_68316180.jpg
#   inflating: fer2013/train/fear/Training_68324804.jpg
#   inflating: fer2013/train/fear/Training_68330823.jpg
#   inflating: fer2013/train/fear/Training_68373853.jpg
#   inflating: fer2013/train/fear/Training_68376662.jpg
#   inflating: fer2013/train/fear/Training_68426401.jpg
#   inflating: fer2013/train/fear/Training_68471741.jpg
#   inflating: fer2013/train/fear/Training_68481958.jpg
#   inflating: fer2013/train/fear/Training_68513545.jpg
#   inflating: fer2013/train/fear/Training_68543785.jpg
#   inflating: fer2013/train/fear/Training_68549907.jpg
#   inflating: fer2013/train/fear/Training_68553300.jpg
#   inflating: fer2013/train/fear/Training_68580200.jpg
#   inflating: fer2013/train/fear/Training_68587609.jpg
#   inflating: fer2013/train/fear/Training_68593351.jpg
#   inflating: fer2013/train/fear/Training_68596982.jpg
#   inflating: fer2013/train/fear/Training_68650901.jpg
#   inflating: fer2013/train/fear/Training_68704847.jpg
#   inflating: fer2013/train/fear/Training_68721153.jpg
#   inflating: fer2013/train/fear/Training_68748817.jpg
#   inflating: fer2013/train/fear/Training_68770831.jpg
#   inflating: fer2013/train/fear/Training_68780637.jpg
#   inflating: fer2013/train/fear/Training_68815743.jpg
#   inflating: fer2013/train/fear/Training_68838596.jpg
#   inflating: fer2013/train/fear/Training_68849468.jpg
#   inflating: fer2013/train/fear/Training_68873649.jpg
#   inflating: fer2013/train/fear/Training_68898978.jpg
#   inflating: fer2013/train/fear/Training_68902307.jpg
#   inflating: fer2013/train/fear/Training_68902401.jpg
#   inflating: fer2013/train/fear/Training_68913193.jpg
#   inflating: fer2013/train/fear/Training_68975361.jpg
#   inflating: fer2013/train/fear/Training_69059792.jpg
#   inflating: fer2013/train/fear/Training_69064246.jpg
#   inflating: fer2013/train/fear/Training_69090470.jpg
#   inflating: fer2013/train/fear/Training_69092745.jpg
#   inflating: fer2013/train/fear/Training_69112102.jpg
#   inflating: fer2013/train/fear/Training_69121395.jpg
#   inflating: fer2013/train/fear/Training_69142865.jpg
#   inflating: fer2013/train/fear/Training_69167308.jpg
#   inflating: fer2013/train/fear/Training_69178322.jpg
#   inflating: fer2013/train/fear/Training_69197345.jpg
#   inflating: fer2013/train/fear/Training_69211699.jpg
#   inflating: fer2013/train/fear/Training_69215959.jpg
#   inflating: fer2013/train/fear/Training_69251402.jpg
#   inflating: fer2013/train/fear/Training_69276948.jpg
#   inflating: fer2013/train/fear/Training_69314965.jpg
#   inflating: fer2013/train/fear/Training_69318595.jpg
#   inflating: fer2013/train/fear/Training_69334745.jpg
#   inflating: fer2013/train/fear/Training_69352812.jpg
#   inflating: fer2013/train/fear/Training_69404354.jpg
#   inflating: fer2013/train/fear/Training_69406379.jpg
#   inflating: fer2013/train/fear/Training_69408967.jpg
#   inflating: fer2013/train/fear/Training_69445044.jpg
#   inflating: fer2013/train/fear/Training_69526111.jpg
#   inflating: fer2013/train/fear/Training_69535836.jpg
#   inflating: fer2013/train/fear/Training_69538802.jpg
#   inflating: fer2013/train/fear/Training_69539458.jpg
#   inflating: fer2013/train/fear/Training_69556360.jpg
#   inflating: fer2013/train/fear/Training_69586263.jpg
#   inflating: fer2013/train/fear/Training_69614417.jpg
#   inflating: fer2013/train/fear/Training_69656943.jpg
#   inflating: fer2013/train/fear/Training_69662650.jpg
#   inflating: fer2013/train/fear/Training_69675216.jpg
#   inflating: fer2013/train/fear/Training_69677094.jpg
#   inflating: fer2013/train/fear/Training_69702472.jpg
#   inflating: fer2013/train/fear/Training_69727827.jpg
#   inflating: fer2013/train/fear/Training_69754609.jpg
#   inflating: fer2013/train/fear/Training_69763159.jpg
#   inflating: fer2013/train/fear/Training_69765387.jpg
#   inflating: fer2013/train/fear/Training_69799062.jpg
#   inflating: fer2013/train/fear/Training_69804558.jpg
#   inflating: fer2013/train/fear/Training_69812475.jpg
#   inflating: fer2013/train/fear/Training_69850844.jpg
#   inflating: fer2013/train/fear/Training_69915590.jpg
#   inflating: fer2013/train/fear/Training_69930748.jpg
#   inflating: fer2013/train/fear/Training_69942287.jpg
#   inflating: fer2013/train/fear/Training_69946449.jpg
#   inflating: fer2013/train/fear/Training_69978783.jpg
#   inflating: fer2013/train/fear/Training_69986901.jpg
#   inflating: fer2013/train/fear/Training_69993467.jpg
#   inflating: fer2013/train/fear/Training_69995155.jpg
#   inflating: fer2013/train/fear/Training_69995908.jpg
#   inflating: fer2013/train/fear/Training_70008241.jpg
#   inflating: fer2013/train/fear/Training_70012504.jpg
#   inflating: fer2013/train/fear/Training_70028702.jpg
#   inflating: fer2013/train/fear/Training_70029967.jpg
#   inflating: fer2013/train/fear/Training_70042615.jpg
#   inflating: fer2013/train/fear/Training_70044810.jpg
#   inflating: fer2013/train/fear/Training_70072371.jpg
#   inflating: fer2013/train/fear/Training_70090121.jpg
#   inflating: fer2013/train/fear/Training_70103350.jpg
#   inflating: fer2013/train/fear/Training_70148590.jpg
#   inflating: fer2013/train/fear/Training_70185141.jpg
#   inflating: fer2013/train/fear/Training_70188670.jpg
#   inflating: fer2013/train/fear/Training_70215228.jpg
#   inflating: fer2013/train/fear/Training_70219404.jpg
#   inflating: fer2013/train/fear/Training_70238279.jpg
#   inflating: fer2013/train/fear/Training_70302155.jpg
#   inflating: fer2013/train/fear/Training_70319713.jpg
#   inflating: fer2013/train/fear/Training_70384498.jpg
#   inflating: fer2013/train/fear/Training_70391013.jpg
#   inflating: fer2013/train/fear/Training_70401159.jpg
#   inflating: fer2013/train/fear/Training_70482016.jpg
#   inflating: fer2013/train/fear/Training_70552459.jpg
#   inflating: fer2013/train/fear/Training_70601395.jpg
#   inflating: fer2013/train/fear/Training_70682430.jpg
#   inflating: fer2013/train/fear/Training_70702021.jpg
#   inflating: fer2013/train/fear/Training_70737529.jpg
#   inflating: fer2013/train/fear/Training_70760624.jpg
#   inflating: fer2013/train/fear/Training_70765319.jpg
#   inflating: fer2013/train/fear/Training_70783857.jpg
#   inflating: fer2013/train/fear/Training_70832810.jpg
#   inflating: fer2013/train/fear/Training_70839925.jpg
#   inflating: fer2013/train/fear/Training_70842347.jpg
#   inflating: fer2013/train/fear/Training_70855689.jpg
#   inflating: fer2013/train/fear/Training_70856782.jpg
#   inflating: fer2013/train/fear/Training_70915221.jpg
#   inflating: fer2013/train/fear/Training_70942319.jpg
#   inflating: fer2013/train/fear/Training_71000748.jpg
#   inflating: fer2013/train/fear/Training_71042019.jpg
#   inflating: fer2013/train/fear/Training_71055343.jpg
#   inflating: fer2013/train/fear/Training_71076892.jpg
#   inflating: fer2013/train/fear/Training_71160831.jpg
#   inflating: fer2013/train/fear/Training_71178037.jpg
#   inflating: fer2013/train/fear/Training_71186440.jpg
#   inflating: fer2013/train/fear/Training_71221210.jpg
#   inflating: fer2013/train/fear/Training_71243139.jpg
#   inflating: fer2013/train/fear/Training_71252339.jpg
#   inflating: fer2013/train/fear/Training_71253631.jpg
#   inflating: fer2013/train/fear/Training_71256206.jpg
#   inflating: fer2013/train/fear/Training_71295913.jpg
#   inflating: fer2013/train/fear/Training_71301064.jpg
#   inflating: fer2013/train/fear/Training_71458330.jpg
#   inflating: fer2013/train/fear/Training_71463288.jpg
#   inflating: fer2013/train/fear/Training_71530326.jpg
#   inflating: fer2013/train/fear/Training_71589001.jpg
#   inflating: fer2013/train/fear/Training_71614284.jpg
#   inflating: fer2013/train/fear/Training_71661776.jpg
#   inflating: fer2013/train/fear/Training_71667940.jpg
#   inflating: fer2013/train/fear/Training_71683079.jpg
#   inflating: fer2013/train/fear/Training_71683325.jpg
#   inflating: fer2013/train/fear/Training_71683349.jpg
#   inflating: fer2013/train/fear/Training_71690796.jpg
#   inflating: fer2013/train/fear/Training_71701620.jpg
#   inflating: fer2013/train/fear/Training_71720333.jpg
#   inflating: fer2013/train/fear/Training_71725800.jpg
#   inflating: fer2013/train/fear/Training_71730769.jpg
#   inflating: fer2013/train/fear/Training_71741660.jpg
#   inflating: fer2013/train/fear/Training_71789771.jpg
#   inflating: fer2013/train/fear/Training_71834753.jpg
#   inflating: fer2013/train/fear/Training_71841966.jpg
#   inflating: fer2013/train/fear/Training_71848443.jpg
#   inflating: fer2013/train/fear/Training_71850108.jpg
#   inflating: fer2013/train/fear/Training_71858736.jpg
#   inflating: fer2013/train/fear/Training_71879183.jpg
#   inflating: fer2013/train/fear/Training_71900042.jpg
#   inflating: fer2013/train/fear/Training_71904248.jpg
#   inflating: fer2013/train/fear/Training_71922027.jpg
#   inflating: fer2013/train/fear/Training_71924958.jpg
#   inflating: fer2013/train/fear/Training_71932154.jpg
#   inflating: fer2013/train/fear/Training_71950688.jpg
#   inflating: fer2013/train/fear/Training_71983993.jpg
#   inflating: fer2013/train/fear/Training_72001003.jpg
#   inflating: fer2013/train/fear/Training_72123767.jpg
#   inflating: fer2013/train/fear/Training_72171519.jpg
#   inflating: fer2013/train/fear/Training_72173994.jpg
#   inflating: fer2013/train/fear/Training_72201956.jpg
#   inflating: fer2013/train/fear/Training_72215905.jpg
#   inflating: fer2013/train/fear/Training_72230521.jpg
#   inflating: fer2013/train/fear/Training_72242223.jpg
#   inflating: fer2013/train/fear/Training_72280830.jpg
#   inflating: fer2013/train/fear/Training_72328939.jpg
#   inflating: fer2013/train/fear/Training_72336361.jpg
#   inflating: fer2013/train/fear/Training_72346301.jpg
#   inflating: fer2013/train/fear/Training_72384727.jpg
#   inflating: fer2013/train/fear/Training_72390463.jpg
#   inflating: fer2013/train/fear/Training_72459451.jpg
#   inflating: fer2013/train/fear/Training_72466819.jpg
#   inflating: fer2013/train/fear/Training_72562583.jpg
#   inflating: fer2013/train/fear/Training_72594654.jpg
#   inflating: fer2013/train/fear/Training_72680423.jpg
#   inflating: fer2013/train/fear/Training_72683073.jpg
#   inflating: fer2013/train/fear/Training_72696747.jpg
#   inflating: fer2013/train/fear/Training_72726748.jpg
#   inflating: fer2013/train/fear/Training_72730228.jpg
#   inflating: fer2013/train/fear/Training_72781676.jpg
#   inflating: fer2013/train/fear/Training_72793415.jpg
#   inflating: fer2013/train/fear/Training_72819557.jpg
#   inflating: fer2013/train/fear/Training_72829778.jpg
#   inflating: fer2013/train/fear/Training_72838252.jpg
#   inflating: fer2013/train/fear/Training_72911220.jpg
#   inflating: fer2013/train/fear/Training_72933913.jpg
#   inflating: fer2013/train/fear/Training_72940322.jpg
#   inflating: fer2013/train/fear/Training_72945974.jpg
#   inflating: fer2013/train/fear/Training_72990380.jpg
#   inflating: fer2013/train/fear/Training_73005690.jpg
#   inflating: fer2013/train/fear/Training_73047568.jpg
#   inflating: fer2013/train/fear/Training_73089459.jpg
#   inflating: fer2013/train/fear/Training_73164626.jpg
#   inflating: fer2013/train/fear/Training_73183671.jpg
#   inflating: fer2013/train/fear/Training_73215063.jpg
#   inflating: fer2013/train/fear/Training_73254742.jpg
#   inflating: fer2013/train/fear/Training_73281243.jpg
#   inflating: fer2013/train/fear/Training_73284884.jpg
#   inflating: fer2013/train/fear/Training_73308751.jpg
#   inflating: fer2013/train/fear/Training_73329034.jpg
#   inflating: fer2013/train/fear/Training_73339296.jpg
#   inflating: fer2013/train/fear/Training_73364336.jpg
#   inflating: fer2013/train/fear/Training_73367013.jpg
#   inflating: fer2013/train/fear/Training_73372272.jpg
#   inflating: fer2013/train/fear/Training_73386002.jpg
#   inflating: fer2013/train/fear/Training_73387860.jpg
#   inflating: fer2013/train/fear/Training_73426228.jpg
#   inflating: fer2013/train/fear/Training_73435997.jpg
#   inflating: fer2013/train/fear/Training_73438575.jpg
#   inflating: fer2013/train/fear/Training_73441660.jpg
#   inflating: fer2013/train/fear/Training_73498575.jpg
#   inflating: fer2013/train/fear/Training_73519831.jpg
#   inflating: fer2013/train/fear/Training_73579378.jpg
#   inflating: fer2013/train/fear/Training_73595423.jpg
#   inflating: fer2013/train/fear/Training_73635549.jpg
#   inflating: fer2013/train/fear/Training_73744376.jpg
#   inflating: fer2013/train/fear/Training_73812342.jpg
#   inflating: fer2013/train/fear/Training_73845317.jpg
#   inflating: fer2013/train/fear/Training_73859563.jpg
#   inflating: fer2013/train/fear/Training_73883523.jpg
#   inflating: fer2013/train/fear/Training_73948541.jpg
#   inflating: fer2013/train/fear/Training_73955485.jpg
#   inflating: fer2013/train/fear/Training_73966221.jpg
#   inflating: fer2013/train/fear/Training_73973742.jpg
#   inflating: fer2013/train/fear/Training_73975231.jpg
#   inflating: fer2013/train/fear/Training_74054781.jpg
#   inflating: fer2013/train/fear/Training_74071103.jpg
#   inflating: fer2013/train/fear/Training_74087362.jpg
#   inflating: fer2013/train/fear/Training_74128243.jpg
#   inflating: fer2013/train/fear/Training_74167144.jpg
#   inflating: fer2013/train/fear/Training_74177530.jpg
#   inflating: fer2013/train/fear/Training_74178312.jpg
#   inflating: fer2013/train/fear/Training_74201940.jpg
#   inflating: fer2013/train/fear/Training_86196253.jpg
#   inflating: fer2013/train/fear/Training_86218505.jpg
#   inflating: fer2013/train/fear/Training_86286445.jpg
#   inflating: fer2013/train/fear/Training_86291469.jpg
#   inflating: fer2013/train/fear/Training_86323976.jpg
#   inflating: fer2013/train/fear/Training_86357524.jpg
#   inflating: fer2013/train/fear/Training_86359726.jpg
#   inflating: fer2013/train/fear/Training_86380480.jpg
#   inflating: fer2013/train/fear/Training_86387892.jpg
#   inflating: fer2013/train/fear/Training_86435046.jpg
#   inflating: fer2013/train/fear/Training_86507565.jpg
#   inflating: fer2013/train/fear/Training_86553920.jpg
#   inflating: fer2013/train/fear/Training_86616037.jpg
#   inflating: fer2013/train/fear/Training_86638824.jpg
#   inflating: fer2013/train/fear/Training_86642449.jpg
#   inflating: fer2013/train/fear/Training_86644633.jpg
#   inflating: fer2013/train/fear/Training_86666905.jpg
#   inflating: fer2013/train/fear/Training_86668660.jpg
#   inflating: fer2013/train/fear/Training_86689248.jpg
#   inflating: fer2013/train/fear/Training_86703654.jpg
#   inflating: fer2013/train/fear/Training_86715318.jpg
#   inflating: fer2013/train/fear/Training_86739643.jpg
#   inflating: fer2013/train/fear/Training_86759124.jpg
#   inflating: fer2013/train/fear/Training_86832766.jpg
#   inflating: fer2013/train/fear/Training_86865290.jpg
#   inflating: fer2013/train/fear/Training_86930489.jpg
#   inflating: fer2013/train/fear/Training_86945452.jpg
#   inflating: fer2013/train/fear/Training_86949063.jpg
#   inflating: fer2013/train/fear/Training_86962533.jpg
#   inflating: fer2013/train/fear/Training_86994688.jpg
#   inflating: fer2013/train/fear/Training_87023572.jpg
#   inflating: fer2013/train/fear/Training_87026511.jpg
#   inflating: fer2013/train/fear/Training_87029979.jpg
#   inflating: fer2013/train/fear/Training_87062150.jpg
#   inflating: fer2013/train/fear/Training_87115439.jpg
#   inflating: fer2013/train/fear/Training_87124147.jpg
#   inflating: fer2013/train/fear/Training_87272289.jpg
#   inflating: fer2013/train/fear/Training_87308235.jpg
#   inflating: fer2013/train/fear/Training_87326040.jpg
#   inflating: fer2013/train/fear/Training_87335410.jpg
#   inflating: fer2013/train/fear/Training_87351438.jpg
#   inflating: fer2013/train/fear/Training_87358265.jpg
#   inflating: fer2013/train/fear/Training_87362866.jpg
#   inflating: fer2013/train/fear/Training_87394233.jpg
#   inflating: fer2013/train/fear/Training_87491540.jpg
#   inflating: fer2013/train/fear/Training_87517030.jpg
#   inflating: fer2013/train/fear/Training_87582525.jpg
#   inflating: fer2013/train/fear/Training_87591546.jpg
#   inflating: fer2013/train/fear/Training_87635406.jpg
#   inflating: fer2013/train/fear/Training_87647952.jpg
#   inflating: fer2013/train/fear/Training_87719007.jpg
#   inflating: fer2013/train/fear/Training_87723970.jpg
#   inflating: fer2013/train/fear/Training_87743488.jpg
#   inflating: fer2013/train/fear/Training_87810830.jpg
#   inflating: fer2013/train/fear/Training_87818024.jpg
#   inflating: fer2013/train/fear/Training_87851920.jpg
#   inflating: fer2013/train/fear/Training_87865449.jpg
#   inflating: fer2013/train/fear/Training_87873349.jpg
#   inflating: fer2013/train/fear/Training_87884962.jpg
#   inflating: fer2013/train/fear/Training_87886125.jpg
#   inflating: fer2013/train/fear/Training_87895152.jpg
#   inflating: fer2013/train/fear/Training_87901249.jpg
#   inflating: fer2013/train/fear/Training_87903138.jpg
#   inflating: fer2013/train/fear/Training_87903666.jpg
#   inflating: fer2013/train/fear/Training_87920724.jpg
#   inflating: fer2013/train/fear/Training_87981577.jpg
#   inflating: fer2013/train/fear/Training_88038728.jpg
#   inflating: fer2013/train/fear/Training_88052893.jpg
#   inflating: fer2013/train/fear/Training_88054161.jpg
#   inflating: fer2013/train/fear/Training_88073663.jpg
#   inflating: fer2013/train/fear/Training_88081911.jpg
#   inflating: fer2013/train/fear/Training_88085394.jpg
#   inflating: fer2013/train/fear/Training_88088826.jpg
#   inflating: fer2013/train/fear/Training_88090454.jpg
#   inflating: fer2013/train/fear/Training_88096426.jpg
#   inflating: fer2013/train/fear/Training_88135811.jpg
#   inflating: fer2013/train/fear/Training_88165263.jpg
#   inflating: fer2013/train/fear/Training_88170709.jpg
#   inflating: fer2013/train/fear/Training_88196605.jpg
#   inflating: fer2013/train/fear/Training_88216107.jpg
#   inflating: fer2013/train/fear/Training_88299723.jpg
#   inflating: fer2013/train/fear/Training_88352658.jpg
#   inflating: fer2013/train/fear/Training_88439345.jpg
#   inflating: fer2013/train/fear/Training_88439684.jpg
#   inflating: fer2013/train/fear/Training_88451302.jpg
#   inflating: fer2013/train/fear/Training_88455936.jpg
#   inflating: fer2013/train/fear/Training_88484938.jpg
#   inflating: fer2013/train/fear/Training_88489850.jpg
#   inflating: fer2013/train/fear/Training_88530257.jpg
#   inflating: fer2013/train/fear/Training_88535299.jpg
#   inflating: fer2013/train/fear/Training_88565292.jpg
#   inflating: fer2013/train/fear/Training_88630615.jpg
#   inflating: fer2013/train/fear/Training_88647115.jpg
#   inflating: fer2013/train/fear/Training_88660457.jpg
#   inflating: fer2013/train/fear/Training_88666991.jpg
#   inflating: fer2013/train/fear/Training_88673713.jpg
#   inflating: fer2013/train/fear/Training_88691232.jpg
#   inflating: fer2013/train/fear/Training_88714175.jpg
#   inflating: fer2013/train/fear/Training_88749455.jpg
#   inflating: fer2013/train/fear/Training_88755071.jpg
#   inflating: fer2013/train/fear/Training_88756840.jpg
#   inflating: fer2013/train/fear/Training_88791820.jpg
#   inflating: fer2013/train/fear/Training_88807796.jpg
#   inflating: fer2013/train/fear/Training_88831227.jpg
#   inflating: fer2013/train/fear/Training_88906865.jpg
#   inflating: fer2013/train/fear/Training_88917157.jpg
#   inflating: fer2013/train/fear/Training_88951145.jpg
#   inflating: fer2013/train/fear/Training_89016091.jpg
#   inflating: fer2013/train/fear/Training_89031934.jpg
#   inflating: fer2013/train/fear/Training_89050041.jpg
#   inflating: fer2013/train/fear/Training_89096197.jpg
#   inflating: fer2013/train/fear/Training_89123510.jpg
#   inflating: fer2013/train/fear/Training_89124066.jpg
#   inflating: fer2013/train/fear/Training_89155187.jpg
#   inflating: fer2013/train/fear/Training_89187908.jpg
#   inflating: fer2013/train/fear/Training_89211493.jpg
#   inflating: fer2013/train/fear/Training_89222305.jpg
#   inflating: fer2013/train/fear/Training_89223896.jpg
#   inflating: fer2013/train/fear/Training_89239029.jpg
#   inflating: fer2013/train/fear/Training_89243899.jpg
#   inflating: fer2013/train/fear/Training_89267810.jpg
#   inflating: fer2013/train/fear/Training_89268024.jpg
#   inflating: fer2013/train/fear/Training_89319883.jpg
#   inflating: fer2013/train/fear/Training_89320674.jpg
#   inflating: fer2013/train/fear/Training_89356500.jpg
#   inflating: fer2013/train/fear/Training_89386308.jpg
#   inflating: fer2013/train/fear/Training_89433093.jpg
#   inflating: fer2013/train/fear/Training_89464263.jpg
#   inflating: fer2013/train/fear/Training_89529453.jpg
#   inflating: fer2013/train/fear/Training_89549024.jpg
#   inflating: fer2013/train/fear/Training_89575609.jpg
#   inflating: fer2013/train/fear/Training_89579037.jpg
#   inflating: fer2013/train/fear/Training_89588176.jpg
#   inflating: fer2013/train/fear/Training_89620277.jpg
#   inflating: fer2013/train/fear/Training_89643824.jpg
#   inflating: fer2013/train/fear/Training_89649221.jpg
#   inflating: fer2013/train/fear/Training_89657133.jpg
#   inflating: fer2013/train/fear/Training_89684349.jpg
#   inflating: fer2013/train/fear/Training_89716625.jpg
#   inflating: fer2013/train/fear/Training_89771940.jpg
#   inflating: fer2013/train/fear/Training_89777169.jpg
#   inflating: fer2013/train/fear/Training_89873943.jpg
#   inflating: fer2013/train/fear/Training_89882062.jpg
#   inflating: fer2013/train/fear/Training_89906385.jpg
#   inflating: fer2013/train/fear/Training_89925102.jpg
#   inflating: fer2013/train/fear/Training_89931272.jpg
#   inflating: fer2013/train/fear/Training_89985124.jpg
#   inflating: fer2013/train/fear/Training_89998154.jpg
#   inflating: fer2013/train/fear/Training_90000251.jpg
#   inflating: fer2013/train/fear/Training_90006164.jpg
#   inflating: fer2013/train/fear/Training_90063711.jpg
#   inflating: fer2013/train/fear/Training_90069123.jpg
#   inflating: fer2013/train/fear/Training_90135006.jpg
#   inflating: fer2013/train/fear/Training_90145064.jpg
#   inflating: fer2013/train/fear/Training_90148108.jpg
#   inflating: fer2013/train/fear/Training_90213112.jpg
#   inflating: fer2013/train/fear/Training_90314753.jpg
#   inflating: fer2013/train/fear/Training_90336031.jpg
#   inflating: fer2013/train/fear/Training_90374410.jpg
#   inflating: fer2013/train/fear/Training_90377115.jpg
#   inflating: fer2013/train/fear/Training_90382892.jpg
#   inflating: fer2013/train/fear/Training_90390677.jpg
#   inflating: fer2013/train/fear/Training_90404688.jpg
#   inflating: fer2013/train/fear/Training_90431564.jpg
#   inflating: fer2013/train/fear/Training_90442444.jpg
#   inflating: fer2013/train/fear/Training_90448424.jpg
#   inflating: fer2013/train/fear/Training_90499367.jpg
#   inflating: fer2013/train/fear/Training_90553507.jpg
#   inflating: fer2013/train/fear/Training_90560520.jpg
#   inflating: fer2013/train/fear/Training_90566252.jpg
#   inflating: fer2013/train/fear/Training_90617831.jpg
#   inflating: fer2013/train/fear/Training_90617849.jpg
#   inflating: fer2013/train/fear/Training_90635707.jpg
#   inflating: fer2013/train/fear/Training_90667776.jpg
#   inflating: fer2013/train/fear/Training_90678533.jpg
#   inflating: fer2013/train/fear/Training_90684260.jpg
#   inflating: fer2013/train/fear/Training_90690028.jpg
#   inflating: fer2013/train/fear/Training_90700692.jpg
#   inflating: fer2013/train/fear/Training_90717505.jpg
#   inflating: fer2013/train/fear/Training_90746169.jpg
#   inflating: fer2013/train/fear/Training_90755578.jpg
#   inflating: fer2013/train/fear/Training_90788470.jpg
#   inflating: fer2013/train/fear/Training_90813066.jpg
#   inflating: fer2013/train/fear/Training_90855578.jpg
#   inflating: fer2013/train/fear/Training_90860488.jpg
#   inflating: fer2013/train/fear/Training_90893446.jpg
#   inflating: fer2013/train/fear/Training_90938861.jpg
#   inflating: fer2013/train/fear/Training_90969633.jpg
#   inflating: fer2013/train/fear/Training_90972539.jpg
#   inflating: fer2013/train/fear/Training_91005353.jpg
#   inflating: fer2013/train/fear/Training_91008891.jpg
#   inflating: fer2013/train/fear/Training_91012221.jpg
#   inflating: fer2013/train/fear/Training_91027749.jpg
#   inflating: fer2013/train/fear/Training_91035569.jpg
#   inflating: fer2013/train/fear/Training_91070801.jpg
#   inflating: fer2013/train/fear/Training_91079950.jpg
#   inflating: fer2013/train/fear/Training_91161249.jpg
#   inflating: fer2013/train/fear/Training_91178645.jpg
#   inflating: fer2013/train/fear/Training_91234340.jpg
#   inflating: fer2013/train/fear/Training_91282946.jpg
#   inflating: fer2013/train/fear/Training_91342300.jpg
#   inflating: fer2013/train/fear/Training_91359583.jpg
#   inflating: fer2013/train/fear/Training_91377853.jpg
#   inflating: fer2013/train/fear/Training_91434212.jpg
#   inflating: fer2013/train/fear/Training_91452710.jpg
#   inflating: fer2013/train/fear/Training_91457708.jpg
#   inflating: fer2013/train/fear/Training_91466839.jpg
#   inflating: fer2013/train/fear/Training_91504819.jpg
#   inflating: fer2013/train/fear/Training_91514574.jpg
#   inflating: fer2013/train/fear/Training_91519876.jpg
#   inflating: fer2013/train/fear/Training_91542766.jpg
#   inflating: fer2013/train/fear/Training_91552954.jpg
#   inflating: fer2013/train/fear/Training_91588777.jpg
#   inflating: fer2013/train/fear/Training_91648182.jpg
#   inflating: fer2013/train/fear/Training_91656667.jpg
#   inflating: fer2013/train/fear/Training_91657048.jpg
#   inflating: fer2013/train/fear/Training_91703839.jpg
#   inflating: fer2013/train/fear/Training_91731723.jpg
#   inflating: fer2013/train/fear/Training_91744656.jpg
#   inflating: fer2013/train/fear/Training_91750517.jpg
#   inflating: fer2013/train/fear/Training_91782114.jpg
#   inflating: fer2013/train/fear/Training_91825354.jpg
#   inflating: fer2013/train/fear/Training_91892302.jpg
#   inflating: fer2013/train/fear/Training_91944715.jpg
#   inflating: fer2013/train/fear/Training_91979523.jpg
#   inflating: fer2013/train/fear/Training_91996560.jpg
#   inflating: fer2013/train/fear/Training_92021165.jpg
#   inflating: fer2013/train/fear/Training_92024508.jpg
#   inflating: fer2013/train/fear/Training_92076632.jpg
#   inflating: fer2013/train/fear/Training_92079033.jpg
#   inflating: fer2013/train/fear/Training_92095105.jpg
#   inflating: fer2013/train/fear/Training_92127745.jpg
#   inflating: fer2013/train/fear/Training_92165833.jpg
#   inflating: fer2013/train/fear/Training_92168412.jpg
#   inflating: fer2013/train/fear/Training_92197097.jpg
#   inflating: fer2013/train/fear/Training_92217712.jpg
#   inflating: fer2013/train/fear/Training_92235969.jpg
#   inflating: fer2013/train/fear/Training_92245499.jpg
#   inflating: fer2013/train/fear/Training_92280160.jpg
#   inflating: fer2013/train/fear/Training_92314057.jpg
#   inflating: fer2013/train/fear/Training_92349096.jpg
#   inflating: fer2013/train/fear/Training_92351271.jpg
#   inflating: fer2013/train/fear/Training_92389048.jpg
#   inflating: fer2013/train/fear/Training_92395444.jpg
#   inflating: fer2013/train/fear/Training_92400462.jpg
#   inflating: fer2013/train/fear/Training_92419956.jpg
#   inflating: fer2013/train/fear/Training_92439925.jpg
#   inflating: fer2013/train/fear/Training_92472970.jpg
#   inflating: fer2013/train/fear/Training_92510823.jpg
#   inflating: fer2013/train/fear/Training_92534929.jpg
#   inflating: fer2013/train/fear/Training_92558983.jpg
#   inflating: fer2013/train/fear/Training_92579050.jpg
#   inflating: fer2013/train/fear/Training_92633065.jpg
#   inflating: fer2013/train/fear/Training_92652283.jpg
#   inflating: fer2013/train/fear/Training_92653741.jpg
#   inflating: fer2013/train/fear/Training_92653969.jpg
#   inflating: fer2013/train/fear/Training_92666544.jpg
#   inflating: fer2013/train/fear/Training_92666768.jpg
#   inflating: fer2013/train/fear/Training_92694913.jpg
#   inflating: fer2013/train/fear/Training_92698411.jpg
#   inflating: fer2013/train/fear/Training_92700611.jpg
#   inflating: fer2013/train/fear/Training_92719790.jpg
#   inflating: fer2013/train/fear/Training_92733372.jpg
# ...
#   inflating: fer2013/train/surprise/Training_91279496.jpg
#   inflating: fer2013/train/surprise/Training_91332118.jpg
#   inflating: fer2013/train/surprise/Training_91396764.jpg
#   inflating: fer2013/train/surprise/Training_91416198.jpg
#   inflating: fer2013/train/surprise/Training_91481863.jpg
#   inflating: fer2013/train/surprise/Training_91530456.jpg
#   inflating: fer2013/train/surprise/Training_91552013.jpg
#   inflating: fer2013/train/surprise/Training_91584251.jpg
#   inflating: fer2013/train/surprise/Training_91587541.jpg
#   inflating: fer2013/train/surprise/Training_91604883.jpg
#   inflating: fer2013/train/surprise/Training_91609012.jpg
#   inflating: fer2013/train/surprise/Training_91662393.jpg
#   inflating: fer2013/train/surprise/Training_91664389.jpg
#   inflating: fer2013/train/surprise/Training_91672224.jpg
#   inflating: fer2013/train/surprise/Training_91683315.jpg
#   inflating: fer2013/train/surprise/Training_91711197.jpg
#   inflating: fer2013/train/surprise/Training_91718342.jpg
#   inflating: fer2013/train/surprise/Training_91818371.jpg
#   inflating: fer2013/train/surprise/Training_91825546.jpg
#   inflating: fer2013/train/surprise/Training_91878559.jpg
#   inflating: fer2013/train/surprise/Training_91914515.jpg
#   inflating: fer2013/train/surprise/Training_91933714.jpg
#   inflating: fer2013/train/surprise/Training_91936114.jpg
#   inflating: fer2013/train/surprise/Training_92044858.jpg
#   inflating: fer2013/train/surprise/Training_92094191.jpg
#   inflating: fer2013/train/surprise/Training_92129253.jpg
#   inflating: fer2013/train/surprise/Training_92151187.jpg
#   inflating: fer2013/train/surprise/Training_92178284.jpg
#   inflating: fer2013/train/surprise/Training_92196145.jpg
#   inflating: fer2013/train/surprise/Training_92209603.jpg
#   inflating: fer2013/train/surprise/Training_92248829.jpg
#   inflating: fer2013/train/surprise/Training_92274884.jpg
#   inflating: fer2013/train/surprise/Training_92312755.jpg
#   inflating: fer2013/train/surprise/Training_92354298.jpg
#   inflating: fer2013/train/surprise/Training_92408940.jpg
#   inflating: fer2013/train/surprise/Training_92423948.jpg
#   inflating: fer2013/train/surprise/Training_92479434.jpg
#   inflating: fer2013/train/surprise/Training_92516152.jpg
#   inflating: fer2013/train/surprise/Training_92532325.jpg
#   inflating: fer2013/train/surprise/Training_92587887.jpg
#   inflating: fer2013/train/surprise/Training_92595345.jpg
#   inflating: fer2013/train/surprise/Training_92606057.jpg
#   inflating: fer2013/train/surprise/Training_92608034.jpg
#   inflating: fer2013/train/surprise/Training_92638202.jpg
#   inflating: fer2013/train/surprise/Training_92652268.jpg
#   inflating: fer2013/train/surprise/Training_92666649.jpg
#   inflating: fer2013/train/surprise/Training_92701859.jpg
#   inflating: fer2013/train/surprise/Training_92768155.jpg
#   inflating: fer2013/train/surprise/Training_92846416.jpg
#   inflating: fer2013/train/surprise/Training_92923337.jpg
#   inflating: fer2013/train/surprise/Training_92984568.jpg
#   inflating: fer2013/train/surprise/Training_93006194.jpg
#   inflating: fer2013/train/surprise/Training_93037336.jpg
#   inflating: fer2013/train/surprise/Training_93055491.jpg
#   inflating: fer2013/train/surprise/Training_93101746.jpg
#   inflating: fer2013/train/surprise/Training_93122504.jpg
#   inflating: fer2013/train/surprise/Training_93172846.jpg
#   inflating: fer2013/train/surprise/Training_93342559.jpg
#   inflating: fer2013/train/surprise/Training_93417164.jpg
#   inflating: fer2013/train/surprise/Training_93442446.jpg
#   inflating: fer2013/train/surprise/Training_93443959.jpg
#   inflating: fer2013/train/surprise/Training_93474212.jpg
#   inflating: fer2013/train/surprise/Training_93492148.jpg
#   inflating: fer2013/train/surprise/Training_93560263.jpg
#   inflating: fer2013/train/surprise/Training_93625113.jpg
#   inflating: fer2013/train/surprise/Training_93625752.jpg
#   inflating: fer2013/train/surprise/Training_93642020.jpg
#   inflating: fer2013/train/surprise/Training_93658821.jpg
#   inflating: fer2013/train/surprise/Training_93675722.jpg
#   inflating: fer2013/train/surprise/Training_93699149.jpg
#   inflating: fer2013/train/surprise/Training_93713521.jpg
#   inflating: fer2013/train/surprise/Training_93735232.jpg
#   inflating: fer2013/train/surprise/Training_93742686.jpg
#   inflating: fer2013/train/surprise/Training_93744466.jpg
#   inflating: fer2013/train/surprise/Training_93747086.jpg
#   inflating: fer2013/train/surprise/Training_93918990.jpg
#   inflating: fer2013/train/surprise/Training_93922116.jpg
#   inflating: fer2013/train/surprise/Training_93942694.jpg
#   inflating: fer2013/train/surprise/Training_93944440.jpg
#   inflating: fer2013/train/surprise/Training_93981745.jpg
#   inflating: fer2013/train/surprise/Training_93997972.jpg
#   inflating: fer2013/train/surprise/Training_94014854.jpg
#   inflating: fer2013/train/surprise/Training_94108784.jpg
#   inflating: fer2013/train/surprise/Training_94164371.jpg
#   inflating: fer2013/train/surprise/Training_94220119.jpg
#   inflating: fer2013/train/surprise/Training_94234220.jpg
#   inflating: fer2013/train/surprise/Training_94244032.jpg
#   inflating: fer2013/train/surprise/Training_94259743.jpg
#   inflating: fer2013/train/surprise/Training_94303347.jpg
#   inflating: fer2013/train/surprise/Training_94363754.jpg
#   inflating: fer2013/train/surprise/Training_94470519.jpg
#   inflating: fer2013/train/surprise/Training_94535865.jpg
#   inflating: fer2013/train/surprise/Training_94582829.jpg
#   inflating: fer2013/train/surprise/Training_94607952.jpg
#   inflating: fer2013/train/surprise/Training_94690773.jpg
#   inflating: fer2013/train/surprise/Training_94690831.jpg
#   inflating: fer2013/train/surprise/Training_94760289.jpg
#   inflating: fer2013/train/surprise/Training_94804140.jpg
#   inflating: fer2013/train/surprise/Training_94815054.jpg
#   inflating: fer2013/train/surprise/Training_94859807.jpg
#   inflating: fer2013/train/surprise/Training_94871392.jpg
#   inflating: fer2013/train/surprise/Training_94872292.jpg
#   inflating: fer2013/train/surprise/Training_94885610.jpg
#   inflating: fer2013/train/surprise/Training_94916496.jpg
#   inflating: fer2013/train/surprise/Training_94931391.jpg
#   inflating: fer2013/train/surprise/Training_95007623.jpg
#   inflating: fer2013/train/surprise/Training_95045198.jpg
#   inflating: fer2013/train/surprise/Training_95079686.jpg
#   inflating: fer2013/train/surprise/Training_95101558.jpg
#   inflating: fer2013/train/surprise/Training_95163599.jpg
#   inflating: fer2013/train/surprise/Training_95187678.jpg
#   inflating: fer2013/train/surprise/Training_95204802.jpg
#   inflating: fer2013/train/surprise/Training_95232145.jpg
#   inflating: fer2013/train/surprise/Training_95310908.jpg
#   inflating: fer2013/train/surprise/Training_95325414.jpg
#   inflating: fer2013/train/surprise/Training_95402552.jpg
#   inflating: fer2013/train/surprise/Training_95451817.jpg
#   inflating: fer2013/train/surprise/Training_95461460.jpg
#   inflating: fer2013/train/surprise/Training_95495690.jpg
#   inflating: fer2013/train/surprise/Training_95558533.jpg
#   inflating: fer2013/train/surprise/Training_95600814.jpg
#   inflating: fer2013/train/surprise/Training_95689131.jpg
#   inflating: fer2013/train/surprise/Training_95699837.jpg
#   inflating: fer2013/train/surprise/Training_95706228.jpg
#   inflating: fer2013/train/surprise/Training_95708850.jpg
#   inflating: fer2013/train/surprise/Training_95755746.jpg
#   inflating: fer2013/train/surprise/Training_95773470.jpg
#   inflating: fer2013/train/surprise/Training_95805741.jpg
#   inflating: fer2013/train/surprise/Training_95830400.jpg
#   inflating: fer2013/train/surprise/Training_95847480.jpg
#   inflating: fer2013/train/surprise/Training_95853103.jpg
#   inflating: fer2013/train/surprise/Training_95880970.jpg
#   inflating: fer2013/train/surprise/Training_95966009.jpg
#   inflating: fer2013/train/surprise/Training_95988339.jpg
#   inflating: fer2013/train/surprise/Training_95989089.jpg
#   inflating: fer2013/train/surprise/Training_96163000.jpg
#   inflating: fer2013/train/surprise/Training_96163370.jpg
#   inflating: fer2013/train/surprise/Training_96193805.jpg
#   inflating: fer2013/train/surprise/Training_96202596.jpg
#   inflating: fer2013/train/surprise/Training_96210289.jpg
#   inflating: fer2013/train/surprise/Training_96238543.jpg
#   inflating: fer2013/train/surprise/Training_96277880.jpg
#   inflating: fer2013/train/surprise/Training_96287206.jpg
#   inflating: fer2013/train/surprise/Training_96389125.jpg
#   inflating: fer2013/train/surprise/Training_96389792.jpg
#   inflating: fer2013/train/surprise/Training_96446762.jpg
#   inflating: fer2013/train/surprise/Training_96475488.jpg
#   inflating: fer2013/train/surprise/Training_96533198.jpg
#   inflating: fer2013/train/surprise/Training_96572434.jpg
#   inflating: fer2013/train/surprise/Training_96596500.jpg
#   inflating: fer2013/train/surprise/Training_96642531.jpg
#   inflating: fer2013/train/surprise/Training_96656714.jpg
#   inflating: fer2013/train/surprise/Training_96661519.jpg
#   inflating: fer2013/train/surprise/Training_96670821.jpg
#   inflating: fer2013/train/surprise/Training_96672701.jpg
#   inflating: fer2013/train/surprise/Training_96695026.jpg
#   inflating: fer2013/train/surprise/Training_96734839.jpg
#   inflating: fer2013/train/surprise/Training_96765324.jpg
#   inflating: fer2013/train/surprise/Training_96765430.jpg
#   inflating: fer2013/train/surprise/Training_96800478.jpg
#   inflating: fer2013/train/surprise/Training_96848455.jpg
#   inflating: fer2013/train/surprise/Training_96914394.jpg
#   inflating: fer2013/train/surprise/Training_96970066.jpg
#   inflating: fer2013/train/surprise/Training_97062924.jpg
#   inflating: fer2013/train/surprise/Training_97090047.jpg
#   inflating: fer2013/train/surprise/Training_97100020.jpg
#   inflating: fer2013/train/surprise/Training_97109955.jpg
#   inflating: fer2013/train/surprise/Training_97149632.jpg
#   inflating: fer2013/train/surprise/Training_97209154.jpg
#   inflating: fer2013/train/surprise/Training_97275390.jpg
#   inflating: fer2013/train/surprise/Training_97284057.jpg
#   inflating: fer2013/train/surprise/Training_97313556.jpg
#   inflating: fer2013/train/surprise/Training_97372586.jpg
#   inflating: fer2013/train/surprise/Training_97386553.jpg
#   inflating: fer2013/train/surprise/Training_97424717.jpg
#   inflating: fer2013/train/surprise/Training_97427205.jpg
#   inflating: fer2013/train/surprise/Training_97427552.jpg
#   inflating: fer2013/train/surprise/Training_97440583.jpg
#   inflating: fer2013/train/surprise/Training_97444585.jpg
#   inflating: fer2013/train/surprise/Training_97615083.jpg
#   inflating: fer2013/train/surprise/Training_97658524.jpg
#   inflating: fer2013/train/surprise/Training_97667504.jpg
#   inflating: fer2013/train/surprise/Training_97675828.jpg
#   inflating: fer2013/train/surprise/Training_97705054.jpg
#   inflating: fer2013/train/surprise/Training_97834691.jpg
#   inflating: fer2013/train/surprise/Training_97847754.jpg
#   inflating: fer2013/train/surprise/Training_97872221.jpg
#   inflating: fer2013/train/surprise/Training_97913254.jpg
#   inflating: fer2013/train/surprise/Training_97921487.jpg
#   inflating: fer2013/train/surprise/Training_97921838.jpg
#   inflating: fer2013/train/surprise/Training_98011942.jpg
#   inflating: fer2013/train/surprise/Training_98062605.jpg
#   inflating: fer2013/train/surprise/Training_98067546.jpg
#   inflating: fer2013/train/surprise/Training_98069171.jpg
#   inflating: fer2013/train/surprise/Training_98079493.jpg
#   inflating: fer2013/train/surprise/Training_98084340.jpg
#   inflating: fer2013/train/surprise/Training_98137653.jpg
#   inflating: fer2013/train/surprise/Training_98160615.jpg
#   inflating: fer2013/train/surprise/Training_98169661.jpg
#   inflating: fer2013/train/surprise/Training_98192978.jpg
#   inflating: fer2013/train/surprise/Training_98197769.jpg
#   inflating: fer2013/train/surprise/Training_98223737.jpg
#   inflating: fer2013/train/surprise/Training_98223779.jpg
#   inflating: fer2013/train/surprise/Training_98234175.jpg
#   inflating: fer2013/train/surprise/Training_98235103.jpg
#   inflating: fer2013/train/surprise/Training_98241018.jpg
#   inflating: fer2013/train/surprise/Training_98315142.jpg
#   inflating: fer2013/train/surprise/Training_98334836.jpg
#   inflating: fer2013/train/surprise/Training_98349673.jpg
#   inflating: fer2013/train/surprise/Training_98352897.jpg
#   inflating: fer2013/train/surprise/Training_98381187.jpg
#   inflating: fer2013/train/surprise/Training_98393554.jpg
#   inflating: fer2013/train/surprise/Training_98397319.jpg
#   inflating: fer2013/train/surprise/Training_98409862.jpg
#   inflating: fer2013/train/surprise/Training_98446939.jpg
#   inflating: fer2013/train/surprise/Training_98447563.jpg
#   inflating: fer2013/train/surprise/Training_98472640.jpg
#   inflating: fer2013/train/surprise/Training_98481914.jpg
#   inflating: fer2013/train/surprise/Training_98511054.jpg
#   inflating: fer2013/train/surprise/Training_98514521.jpg
#   inflating: fer2013/train/surprise/Training_98539906.jpg
#   inflating: fer2013/train/surprise/Training_98569897.jpg
#   inflating: fer2013/train/surprise/Training_98576352.jpg
#   inflating: fer2013/train/surprise/Training_98588726.jpg
#   inflating: fer2013/train/surprise/Training_98594534.jpg
#   inflating: fer2013/train/surprise/Training_98644924.jpg
#   inflating: fer2013/train/surprise/Training_98657632.jpg
#   inflating: fer2013/train/surprise/Training_98664620.jpg
#   inflating: fer2013/train/surprise/Training_98737557.jpg
#   inflating: fer2013/train/surprise/Training_98747340.jpg
#   inflating: fer2013/train/surprise/Training_98750930.jpg
#   inflating: fer2013/train/surprise/Training_98758885.jpg
#   inflating: fer2013/train/surprise/Training_98767792.jpg
#   inflating: fer2013/train/surprise/Training_98774734.jpg
#   inflating: fer2013/train/surprise/Training_98827007.jpg
#   inflating: fer2013/train/surprise/Training_98828949.jpg
#   inflating: fer2013/train/surprise/Training_98840937.jpg
#   inflating: fer2013/train/surprise/Training_98861159.jpg
#   inflating: fer2013/train/surprise/Training_98899707.jpg
#   inflating: fer2013/train/surprise/Training_98971238.jpg
#   inflating: fer2013/train/surprise/Training_98972491.jpg
#   inflating: fer2013/train/surprise/Training_99066709.jpg
#   inflating: fer2013/train/surprise/Training_99104204.jpg
#   inflating: fer2013/train/surprise/Training_99106305.jpg
#   inflating: fer2013/train/surprise/Training_99113691.jpg
#   inflating: fer2013/train/surprise/Training_99182527.jpg
#   inflating: fer2013/train/surprise/Training_99233432.jpg
#   inflating: fer2013/train/surprise/Training_99267647.jpg
#   inflating: fer2013/train/surprise/Training_99279802.jpg
#   inflating: fer2013/train/surprise/Training_99318660.jpg
#   inflating: fer2013/train/surprise/Training_99399304.jpg
#   inflating: fer2013/train/surprise/Training_99399823.jpg
#   inflating: fer2013/train/surprise/Training_99404349.jpg
#   inflating: fer2013/train/surprise/Training_99441101.jpg
#   inflating: fer2013/train/surprise/Training_99576616.jpg
#   inflating: fer2013/train/surprise/Training_99604118.jpg
#   inflating: fer2013/train/surprise/Training_99663019.jpg
#   inflating: fer2013/train/surprise/Training_99791966.jpg
#   inflating: fer2013/train/surprise/Training_99794165.jpg
#   inflating: fer2013/train/surprise/Training_99807705.jpg
#   inflating: fer2013/train/surprise/Training_99827442.jpg
#   inflating: fer2013/train/surprise/Training_99916297.jpg
#   inflating: fer2013/train/surprise/Training_99924420.jpg
#   inflating: fer2013/train/surprise/Training_99937001.jpg
#   inflating: fer2013/train/surprise/Training_99951755.jpg
#   inflating: fer2013/train/surprise/Training_99984132.jpg

# %%
# !python --version
import torch
torch.__version__
# Out:
# Python 3.10.12
# '2.1.0+cu121'

# %% [markdown]
# # preprocessing train

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale = 1./255,   ## rescale or normalize the images pixels, by dividing them 255
    shear_range = 0.2,  ## angle for slant of image in degrees
    zoom_range = 0.2,   ## for zoom in or out
    horizontal_flip = True
)
training_set = train_datagen.flow_from_directory(
    '/content/fer2013/train',   ## give path of training set
    target_size=(48,48),      ## target_size of image in which you want
    batch_size=64,
    color_mode = "grayscale",
    class_mode = 'categorical'
)
# Out:
# Found 6881 images belonging to 7 classes.

# %% [markdown]
# # preprocessing test

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(
    '/content/fer2013/test',
    target_size = (48,48),
    batch_size = 64,
    color_mode = "grayscale",
    class_mode = 'categorical'
)
# Out:
# Found 2942 images belonging to 7 classes.

# %% [markdown]
# #Building the CNN Model¶

# %%
def get_model(input_size, classes=7):
     #Initialising the CNN
    model = tf.keras.models.Sequential()

    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_size))
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2, 2))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(512, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Conv2D(512, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))


    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(classes, activation='softmax'))

    #Compliling the model
    model.compile(optimizer=Adam(lr=0.0001, decay=1e-6),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax
model.compile(optimizer = Adam(lr=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# %% [markdown]
# # training model

# %%
## Training the model
from keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=4, verbose=1)
history = model.fit(training_set,
                    epochs=60,
                    batch_size=64,
                    validation_data = test_set,
                    shuffle=True,
                    callbacks = [early_stop]
                   )
# Out:
# Epoch 1/60
# 108/108 [==============================] - 17s 83ms/step - loss: 2.2330 - accuracy: 0.1901 - val_loss: 2.5238 - val_accuracy: 0.1523
# Epoch 2/60
# 108/108 [==============================] - 9s 80ms/step - loss: 2.0178 - accuracy: 0.2253 - val_loss: 2.1624 - val_accuracy: 0.1621
# Epoch 3/60
# 108/108 [==============================] - 7s 64ms/step - loss: 1.9267 - accuracy: 0.2537 - val_loss: 2.0597 - val_accuracy: 0.1937
# Epoch 4/60
# 108/108 [==============================] - 9s 81ms/step - loss: 1.8475 - accuracy: 0.2821 - val_loss: 2.5725 - val_accuracy: 0.1642
# Epoch 5/60
# 108/108 [==============================] - 7s 65ms/step - loss: 1.7932 - accuracy: 0.3029 - val_loss: 2.0516 - val_accuracy: 0.2128
# Epoch 6/60
# 108/108 [==============================] - 9s 81ms/step - loss: 1.7143 - accuracy: 0.3373 - val_loss: 1.7620 - val_accuracy: 0.2801
# Epoch 7/60
# 108/108 [==============================] - 7s 66ms/step - loss: 1.6704 - accuracy: 0.3623 - val_loss: 1.6503 - val_accuracy: 0.3457
# Epoch 8/60
# 108/108 [==============================] - 9s 80ms/step - loss: 1.6018 - accuracy: 0.3824 - val_loss: 1.8052 - val_accuracy: 0.2607
# Epoch 9/60
# 108/108 [==============================] - 7s 65ms/step - loss: 1.5510 - accuracy: 0.4058 - val_loss: 1.4544 - val_accuracy: 0.4395
# Epoch 10/60
# 108/108 [==============================] - 9s 80ms/step - loss: 1.4861 - accuracy: 0.4264 - val_loss: 1.4698 - val_accuracy: 0.4307
# Epoch 11/60
# 108/108 [==============================] - 7s 66ms/step - loss: 1.4435 - accuracy: 0.4435 - val_loss: 1.5994 - val_accuracy: 0.3923
# Epoch 12/60
# 108/108 [==============================] - 7s 63ms/step - loss: 1.3946 - accuracy: 0.4575 - val_loss: 1.4056 - val_accuracy: 0.4579
# Epoch 13/60
# 108/108 [==============================] - 9s 81ms/step - loss: 1.3470 - accuracy: 0.4816 - val_loss: 1.4236 - val_accuracy: 0.4613
# Epoch 14/60
# 108/108 [==============================] - 7s 65ms/step - loss: 1.2910 - accuracy: 0.5091 - val_loss: 1.4364 - val_accuracy: 0.4558
# Epoch 15/60
# 108/108 [==============================] - 9s 81ms/step - loss: 1.2756 - accuracy: 0.5113 - val_loss: 1.3984 - val_accuracy: 0.4483
# Epoch 16/60
# 108/108 [==============================] - 7s 63ms/step - loss: 1.2444 - accuracy: 0.5281 - val_loss: 1.4315 - val_accuracy: 0.4701
# Epoch 17/60
# 108/108 [==============================] - 9s 82ms/step - loss: 1.2159 - accuracy: 0.5416 - val_loss: 1.2940 - val_accuracy: 0.5014
# Epoch 18/60
# 108/108 [==============================] - 7s 67ms/step - loss: 1.1840 - accuracy: 0.5506 - val_loss: 1.2643 - val_accuracy: 0.5228
# Epoch 19/60
# 108/108 [==============================] - 9s 79ms/step - loss: 1.1435 - accuracy: 0.5621 - val_loss: 1.3062 - val_accuracy: 0.5224
# Epoch 20/60
# 108/108 [==============================] - 7s 64ms/step - loss: 1.1099 - accuracy: 0.5831 - val_loss: 1.4046 - val_accuracy: 0.4854
# Epoch 21/60
# 108/108 [==============================] - 9s 80ms/step - loss: 1.0783 - accuracy: 0.5881 - val_loss: 1.4343 - val_accuracy: 0.4776
# Epoch 22/60
# 108/108 [==============================] - 7s 69ms/step - loss: 1.0848 - accuracy: 0.5905 - val_loss: 1.2873 - val_accuracy: 0.4952
# Epoch 22: early stopping

# %%
train_loss, train_acc = model.evaluate(training_set)
test_loss, test_acc   = model.evaluate(test_set)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_acc*100, test_acc*100))
# Out:
# 108/108 [==============================] - 7s 61ms/step - loss: 1.0642 - accuracy: 0.6021
# 46/46 [==============================] - 1s 23ms/step - loss: 1.2873 - accuracy: 0.4952
# final train accuracy = 60.21 , validation accuracy = 49.52

# %%
import matplotlib.pyplot as plt
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %% [markdown]
# # test the model performance

# %%
import numpy as np
model.save('CNN_model.h5')
from keras.utils import load_img
img = load_img("/content/fer2013/test/surprise/PublicTest_15712657.jpg",target_size = (48,48),color_mode = "grayscale")
img = np.array(img)
plt.imshow(img)
print(img.shape)
#====================================================================================
training_set.class_indices
label_dict = ['angry', 'disgust', 'fear','happy', 'neutral', 'sad', 'surprise']

#============================================================================
from keras.utils import img_to_array
test_image = img_to_array(img)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
result[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# (48, 48)
# 1/1 [==============================] - 1s 716ms/step
# array([2.1362577e-16, 3.7943858e-38, 1.2098269e-19, 0.0000000e+00,
#        1.2535354e-14, 0.0000000e+00, 1.0000000e+00], dtype=float32)

# %%
res = np.argmax(result[0])
print('predicted Label for that image is: {}'.format(label_dict[res]))
# Out:
# predicted Label for that image is: surprise

# %% [markdown]
# # pretrained vgg16

# %%
train_dir = '/content/fer2013/train'
test_dir = '/content/fer2013/test'


train_transform = transforms.Compose([transforms.Resize((224, 224)),])
# Define the test_transform using Compose and Resize
test_transform = transforms.Compose([transforms.Resize((224, 224)),])
# Use ImageFolder to create dataset(s)
train_data = datasets.ImageFolder(train_dir, transform=train_transform)  # Fix variable name
test_data = datasets.ImageFolder(test_dir, transform=test_transform)  # Fix variable name


base_model = tf.keras.applications.VGG16(input_shape=(48,48,3),include_top=False,weights="imagenet")


# Freezing Layers

for layer in base_model.layers[:-4]:
    layer.trainable=False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
# Building Model
model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(7,activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  dropout (Dropout)           (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dense (Dense)               (None, 32)                16416
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation (Activation)     (None, 32)                0
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  batch_normalization_2 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32)                0
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_2 (Activation)   (None, 32)                0
#
#  dense_3 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 14735879 (56.21 MB)
# Trainable params: 7099399 (27.08 MB)
# Non-trainable params: 7636480 (29.13 MB)
# _________________________________________________________________

# %%
#accuracy scores
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]




lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 20,verbose = 1,factor = 0.50, min_lr = 1e-10)

mcp = ModelCheckpoint('model.h5')

es = EarlyStopping(verbose=1, patience=20)


model.compile(optimizer='Adam', loss='categorical_crossentropy',metrics=METRICS)

# %%
#get train, val and test datasets
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,

        rotation_range=5,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        #zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255
                                  )
train_dataset  = train_datagen.flow_from_directory(directory = '/content/fer2013/train',
                                                   target_size = (48,48),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 64)
valid_dataset = valid_datagen.flow_from_directory(directory = '/content/fer2013/train',
                                                  target_size = (48,48),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 64)
test_dataset = test_datagen.flow_from_directory(directory = '/content/fer2013/test',
                                                  target_size = (48,48),
                                                  class_mode = 'categorical',
                                                  batch_size = 64)


#fit the model
history=model.fit(train_dataset,validation_data=valid_dataset,epochs = 5,verbose = 1,callbacks=[lrd,mcp,es])
# Out:
# Found 5508 images belonging to 7 classes.
# Found 1373 images belonging to 7 classes.
# Found 2942 images belonging to 7 classes.
# Epoch 1/5
#  5/87 [>.............................] - ETA: 6:39 - loss: 1.9050 - accuracy: 0.8567 - precision: 0.4000 - recall: 0.0063 - auc: 0.5993 - f1_score: 0.0122

# %%
#PLOTTING RESULTS (Train vs Validation)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):

    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()


Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )

# %%
history=model.fit(train_dataset,validation_data=valid_dataset,epochs = 5,verbose = 1,callbacks=[lrd,mcp,es])

# %%
# Evaluate the model on the test dataset
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_f1 = model.evaluate(test_dataset)
# Print the accuracy
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Print other metrics if needed
print(f'Test Precision: {test_precision:.4f}')
print(f'Test Recall: {test_recall:.4f}')
print(f'Test AUC: {test_auc:.4f}')
print(f'Test F1 Score: {test_f1:.4f}')

# %%
VGG16_Predictions = model.predict(test_dataset)

# Choosing the highest probability class in every prediction
VGG16_Predictions = np.argmax(VGG16_Predictions, axis=1)

# Shuffling Test Data to show different classes
test_preprocessor = ImageDataGenerator(
    rescale=1 / 255.,
)

test_generator = test_preprocessor.flow_from_directory(
    test_dir,
    class_mode="categorical",
    target_size=(48, 48),
    color_mode="rgb",
    shuffle=True,
    batch_size=64,
)
Emotion_Classes = ['Angry',
                  'Disgust',
                  'Fear',
                  'Happy',
                  'Neutral',
                  'Sad',
                  'Surprise']

# Display 10 random pictures from the dataset with their labels
Random_batch = np.random.randint(0, len(test_generator) - 1)

Random_Img_Index = np.random.randint(0, 64 - 1, 10)

fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(25, 10),
                         subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    Random_Img, Random_Img_Label = test_generator[Random_batch][0][Random_Img_Index[i]], \
                                   np.argmax(test_generator[Random_batch][1][Random_Img_Index[i]])

    Model_Prediction = np.argmax(model.predict(tf.expand_dims(Random_Img, axis=0), verbose=0))

    ax.imshow(Random_Img)

    if Emotion_Classes[Random_Img_Label] == Emotion_Classes[Model_Prediction]:
        color = "green"
    else:
        color = "red"
    ax.set_title(f"True: {Emotion_Classes[Random_Img_Label]}\nPredicted: {Emotion_Classes[Model_Prediction]}", color=color)

plt.show()
plt.tight_layout()

# %% [markdown]
# # transformer viT

# %%
import matplotlib.pyplot as plt
import torch
import torchvision

from torch import nn
from torchvision import transforms
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
import torchvision
# Define the train_transform using Compose
train_transform = torchvision.transforms.Compose([
     torchvision.transforms.Resize((224, 224)),
     torchvision.transforms.ToTensor()
])

# Define the test_transform using Compose
test_transform = torchvision.transforms.Compose([
     torchvision.transforms.Resize((224, 224)),
     torchvision.transforms.ToTensor()
])

# %%
# Setup directory paths to train and test images
train_dir = '/content/fer2013/train'
test_dir = '/content/fer2013/test'
# Create the training dataset using ImageFolder
#train_dataset = ImageFolder(root='/content/train', transform=train_transform)

# Create the test dataset using ImageFolder
#test_dataset = ImageFolder(root='/content/test' , transform=test_transform)

# %%
import os

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

NUM_WORKERS = os.cpu_count()

def create_dataloaders(
    train_dir: str,
    test_dir: str,
    transform: transforms.Compose,
    batch_size: int,
    num_workers: int=NUM_WORKERS
):

  # Use ImageFolder to create dataset(s)
  train_data = datasets.ImageFolder(train_dir, transform=transform)
  test_data = datasets.ImageFolder(test_dir, transform=transform)

  # Get class names
  class_names = train_data.classes

  # Turn images into data loaders
  train_dataloader = DataLoader(
      train_data,
      batch_size=batch_size,
      shuffle=True,
      num_workers=num_workers,
      pin_memory=True,
  )
  test_dataloader = DataLoader(
      test_data,
      batch_size=batch_size,
      shuffle=False,
      num_workers=num_workers,
      pin_memory=True,
  )

  return train_dataloader, test_dataloader, class_names

# %%
# Create image size
IMG_SIZE = 224

# Create transform pipeline manually
manual_transforms = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
])
print(f"Manually created transforms: {manual_transforms}")
# Out:
# Manually created transforms: Compose(
#     Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=warn)
#     ToTensor()
# )

# %%
# Set the batch size
BATCH_SIZE = 32

# Create data loaders
train_dataloader, test_dataloader, class_names = create_dataloaders(
    train_dir=train_dir,
    test_dir=test_dir,
    transform=manual_transforms,
    batch_size=BATCH_SIZE
)

train_dataloader, test_dataloader, class_names
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x791bf28a6d10>,
#  <torch.utils.data.dataloader.DataLoader at 0x791bf28a69e0>,
#  ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise'])

# %%
# Let's visualize a image in order to know if data is loaded properly or not

# Get a batch of images
image_batch, label_batch = next(iter(train_dataloader))

# Get a single image from the batch
image, label = image_batch[0], label_batch[0]

# View the batch shapes
print(image.shape, label)

# Plot image with matplotlib
plt.imshow(image.permute(1, 2, 0)) # rearrange image dimensions to suit matplotlib [color_channels, height, width] -> [height, width, color_channels]
plt.title(class_names[label])
plt.axis(False);
# Out:
# torch.Size([3, 224, 224]) tensor(3)

# %%
# 1. Create a class which subclasses nn.Module
class PatchEmbedding(nn.Module):
    """Turns a 2D input image into a 1D sequence learnable embedding vector.

    Args:
        in_channels (int): Number of color channels for the input images. Defaults to 3.
        patch_size (int): Size of patches to convert input image into. Defaults to 16.
        embedding_dim (int): Size of embedding to turn image into. Defaults to 768.
    """
    # 2. Initialize the class with appropriate variables
    def __init__(self,
                 in_channels:int=3,
                 patch_size:int=16,
                 embedding_dim:int=768):
        super().__init__()

        # 3. Create a layer to turn an image into patches
        self.patcher = nn.Conv2d(in_channels=in_channels,
                                 out_channels=embedding_dim,
                                 kernel_size=patch_size,
                                 stride=patch_size,
                                 padding=0)

        # 4. Create a layer to flatten the patch feature maps into a single dimension
        self.flatten = nn.Flatten(start_dim=2, # only flatten the feature map dimensions into a single vector
                                  end_dim=3)

    # 5. Define the forward method
    def forward(self, x):
        # Create assertion to check that inputs are the correct shape
        image_resolution = x.shape[-1]
        assert image_resolution % patch_size == 0, f"Input image size must be divisble by patch size, image shape: {image_resolution}, patch size: {patch_size}"

        # Perform the forward pass
        x_patched = self.patcher(x)
        x_flattened = self.flatten(x_patched)

        # 6. Make sure the output shape has the right order
        return x_flattened.permute(0, 2, 1) # adjust so the embedding is on the final dimension [batch_size, P^2•C, N] -> [batch_

# %%
# Let's test it on single image
patch_size =16

# Set seeds
def set_seeds(seed: int=42):
    """Sets random sets for torch operations.

    Args:
        seed (int, optional): Random seed to set. Defaults to 42.
    """
    # Set the seed for general torch operations
    torch.manual_seed(seed)
    # Set the seed for CUDA torch operations (ones that happen on the GPU)
    torch.cuda.manual_seed(seed)



set_seeds()

# Create an instance of patch embedding layer
patchify = PatchEmbedding(in_channels=3,
                          patch_size=16,
                          embedding_dim=768)

# Pass a single image through
print(f"Input image shape: {image.unsqueeze(0).shape}")
patch_embedded_image = patchify(image.unsqueeze(0)) # add an extra batch dimension on the 0th index, otherwise will error
print(f"Output patch embedding shape: {patch_embedded_image.shape}")
# Out:
# Input image shape: torch.Size([1, 3, 224, 224])
# Output patch embedding shape: torch.Size([1, 196, 768])

# %%
# View the patch embedding and patch embedding shape


print(patch_embedded_image)
print(f"Patch embedding shape: {patch_embedded_image.shape} -> [batch_size, number_of_patches, embedding_dimension]")
# Out:
# tensor([[[-0.1488,  0.0231, -0.0696,  ...,  0.1155, -0.0658,  0.0535],
#          [-0.1988,  0.0707, -0.1278,  ...,  0.1629, -0.0813,  0.0453],
#          [-0.2336,  0.0347, -0.0917,  ...,  0.1751, -0.1116,  0.1465],
#          ...,
#          [-0.3028,  0.0978, -0.1355,  ...,  0.2558, -0.1588,  0.1320],
#          [-0.3083,  0.0375, -0.1934,  ...,  0.2560, -0.0816,  0.1399],
#          [-0.1044,  0.0235, -0.2179,  ...,  0.1626, -0.0325,  0.1749]]],
#        grad_fn=<PermuteBackward0>)
# Patch embedding shape: torch.Size([1, 196, 768]) -> [batch_size, number_of_patches, embedding_dimension]

# %%
# Now add the the learnable class embedding and position embeddings
# From start to positional encoding: All in 1 cell

set_seeds()

# 1. Set patch size
patch_size = 16

# 2. Print shape of original image tensor and get the image dimensions
print(f"Image tensor shape: {image.shape}")
height, width = image.shape[1], image.shape[2]

# 3. Get image tensor and add batch dimension
x = image.unsqueeze(0)
print(f"Input image with batch dimension shape: {x.shape}")

# 4. Create patch embedding layer
patch_embedding_layer = PatchEmbedding(in_channels=3,
                                       patch_size=patch_size,
                                       embedding_dim=768)

# 5. Pass image through patch embedding layer
patch_embedding = patch_embedding_layer(x)
print(f"Patching embedding shape: {patch_embedding.shape}")


# 6. Create class token embedding
batch_size = patch_embedding.shape[0]
embedding_dimension = patch_embedding.shape[-1]
class_token = nn.Parameter(torch.ones(batch_size, 1, embedding_dimension),
                           requires_grad=True) # make sure it's learnable
print(f"Class token embedding shape: {class_token.shape}")

# 7. Prepend class token embedding to patch embedding
patch_embedding_class_token = torch.cat((class_token, patch_embedding), dim=1)
print(f"Patch embedding with class token shape: {patch_embedding_class_token.shape}")

# 8. Create position embedding
number_of_patches = int((height * width) / patch_size**2)
position_embedding = nn.Parameter(torch.ones(1, number_of_patches+1, embedding_dimension),
                                  requires_grad=True) # make sure it's learnable


# 9. Add position embedding to patch embedding with class token
patch_and_position_embedding = patch_embedding_class_token + position_embedding
print(f"Patch and position embedding shape: {patch_and_position_embedding.shape}")
#patch_and_position_embedding

print(patch_embedding_class_token)  #1 is added in the beginning of each
# Out:
# Image tensor shape: torch.Size([3, 224, 224])
# Input image with batch dimension shape: torch.Size([1, 3, 224, 224])
# Patching embedding shape: torch.Size([1, 196, 768])
# Class token embedding shape: torch.Size([1, 1, 768])
# Patch embedding with class token shape: torch.Size([1, 197, 768])
# Patch and position embedding shape: torch.Size([1, 197, 768])
# tensor([[[ 1.0000,  1.0000,  1.0000,  ...,  1.0000,  1.0000,  1.0000],
#          [-0.1488,  0.0231, -0.0696,  ...,  0.1155, -0.0658,  0.0535],
#          [-0.1988,  0.0707, -0.1278,  ...,  0.1629, -0.0813,  0.0453],
#          ...,
#          [-0.3028,  0.0978, -0.1355,  ...,  0.2558, -0.1588,  0.1320],
#          [-0.3083,  0.0375, -0.1934,  ...,  0.2560, -0.0816,  0.1399],
#          [-0.1044,  0.0235, -0.2179,  ...,  0.1626, -0.0325,  0.1749]]],
#        grad_fn=<CatBackward0>)

# %%
# 1. Create a class that inherits from nn.Module
class MultiheadSelfAttentionBlock(nn.Module):
    """Creates a multi-head self-attention block ("MSA block" for short).
    """
    # 2. Initialize the class with hyperparameters from Table 1
    def __init__(self,
                 embedding_dim:int=768, # Hidden size D from Table 1 for ViT-Base
                 num_heads:int=12, # Heads from Table 1 for ViT-Base
                 attn_dropout:float=0): # doesn't look like the paper uses any dropout in MSABlocks
        super().__init__()

        # 3. Create the Norm layer (LN)
        self.layer_norm = nn.LayerNorm(normalized_shape=embedding_dim)

        # 4. Create the Multi-Head Attention (MSA) layer
        self.multihead_attn = nn.MultiheadAttention(embed_dim=embedding_dim,
                                                    num_heads=num_heads,
                                                    dropout=attn_dropout,
                                                    batch_first=True) # does our batch dimension come first?

    # 5. Create a forward() method to pass the data throguh the layers
    def forward(self, x):
        x = self.layer_norm(x)
        attn_output, _ = self.multihead_attn(query=x, # query embeddings
                                             key=x, # key embeddings
                                             value=x, # value embeddings
                                             need_weights=False) # do we need the weights or just the layer outputs?
        return attn_output

# %%
# 1. Create a class that inherits from nn.Module
class MLPBlock(nn.Module):
    """Creates a layer normalized multilayer perceptron block ("MLP block" for short)."""
    # 2. Initialize the class with hyperparameters from Table 1 and Table 3
    def __init__(self,
                 embedding_dim:int=768, # Hidden Size D from Table 1 for ViT-Base
                 mlp_size:int=3072, # MLP size from Table 1 for ViT-Base
                 dropout:float=0.1): # Dropout from Table 3 for ViT-Base
        super().__init__()

        # 3. Create the Norm layer (LN)
        self.layer_norm = nn.LayerNorm(normalized_shape=embedding_dim)

        # 4. Create the Multilayer perceptron (MLP) layer(s)
        self.mlp = nn.Sequential(
            nn.Linear(in_features=embedding_dim,
                      out_features=mlp_size),
            nn.GELU(), # "The MLP contains two layers with a GELU non-linearity (section 3.1)."
            nn.Dropout(p=dropout),
            nn.Linear(in_features=mlp_size, # needs to take same in_features as out_features of layer above
                      out_features=embedding_dim), # take back to embedding_dim
            nn.Dropout(p=dropout) # "Dropout, when used, is applied after every dense layer.."
        )

    # 5. Create a forward() method to pass the data throguh the layers
    def forward(self, x):
        x = self.layer_norm(x)
        x = self.mlp(x)
        return x

# %%
# 1. Create a class that inherits from nn.Module
class TransformerEncoderBlock(nn.Module):
    """Creates a Transformer Encoder block."""
    # 2. Initialize the class with hyperparameters from Table 1 and Table 3
    def __init__(self,
                 embedding_dim:int=768, # Hidden size D from Table 1 for ViT-Base
                 num_heads:int=12, # Heads from Table 1 for ViT-Base
                 mlp_size:int=3072, # MLP size from Table 1 for ViT-Base
                 mlp_dropout:float=0.1, # Amount of dropout for dense layers from Table 3 for ViT-Base
                 attn_dropout:float=0): # Amount of dropout for attention layers
        super().__init__()

        # 3. Create MSA block (equation 2)
        self.msa_block = MultiheadSelfAttentionBlock(embedding_dim=embedding_dim,
                                                     num_heads=num_heads,
                                                     attn_dropout=attn_dropout)

        # 4. Create MLP block (equation 3)
        self.mlp_block =  MLPBlock(embedding_dim=embedding_dim,
                                   mlp_size=mlp_size,
                                   dropout=mlp_dropout)

    # 5. Create a forward() method
    def forward(self, x):

        # 6. Create residual connection for MSA block (add the input to the output)
        x =  self.msa_block(x) + x
         # 7. Create residual connection for MLP block (add the input to the output)
        x = self.mlp_block(x) + x

        return x

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
transformer_encoder_block = TransformerEncoderBlock()

from torchinfo import summary
# # Print an input and output summary of our Transformer Encoder (uncomment for full output)
summary(model=transformer_encoder_block,
        input_size=(1, 197, 768), # (batch_size, num_patches, embedding_dimension)
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
       row_settings=["var_names"])
# Out:
# ==================================================================================================================================
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ==================================================================================================================================
# TransformerEncoderBlock (TransformerEncoderBlock)  [1, 197, 768]        [1, 197, 768]        --                   True
# ├─MultiheadSelfAttentionBlock (msa_block)          [1, 197, 768]        [1, 197, 768]        --                   True
# │    └─LayerNorm (layer_norm)                      [1, 197, 768]        [1, 197, 768]        1,536                True
# │    └─MultiheadAttention (multihead_attn)         --                   [1, 197, 768]        2,362,368            True
# ├─MLPBlock (mlp_block)                             [1, 197, 768]        [1, 197, 768]        --                   True
# │    └─LayerNorm (layer_norm)                      [1, 197, 768]        [1, 197, 768]        1,536                True
# │    └─Sequential (mlp)                            [1, 197, 768]        [1, 197, 768]        --                   True
# │    │    └─Linear (0)                             [1, 197, 768]        [1, 197, 3072]       2,362,368            True
# │    │    └─GELU (1)                               [1, 197, 3072]       [1, 197, 3072]       --                   --
# │    │    └─Dropout (2)                            [1, 197, 3072]       [1, 197, 3072]       --                   --
# │    │    └─Linear (3)                             [1, 197, 3072]       [1, 197, 768]        2,360,064            True
# │    │    └─Dropout (4)                            [1, 197, 768]        [1, 197, 768]        --                   --
# ==================================================================================================================================
# Total params: 7,087,872
# Trainable params: 7,087,872
# Non-trainable params: 0
# Total mult-adds (M): 4.73
# ==================================================================================================================================
# Input size (MB): 0.61
# Forward/backward pass size (MB): 8.47
# Params size (MB): 18.90
# Estimated Total Size (MB): 27.98
# ==================================================================================================================================

# %%
# 1. Create a ViT class that inherits from nn.Module
class ViT(nn.Module):
    """Creates a Vision Transformer architecture with ViT-Base hyperparameters by default."""
    # 2. Initialize the class with hyperparameters from Table 1 and Table 3
    def __init__(self,
                 img_size:int=224, # Training resolution from Table 3 in ViT paper
                 in_channels:int=3, # Number of channels in input image
                 patch_size:int=16, # Patch size
                 num_transformer_layers:int=12, # Layers from Table 1 for ViT-Base
                 embedding_dim:int=768, # Hidden size D from Table 1 for ViT-Base
                 mlp_size:int=3072, # MLP size from Table 1 for ViT-Base
                 num_heads:int=12, # Heads from Table 1 for ViT-Base
                 attn_dropout:float=0, # Dropout for attention projection
                 mlp_dropout:float=0.1, # Dropout for dense/MLP layers
                 embedding_dropout:float=0.1, # Dropout for patch and position embeddings
                 num_classes:int=1000): # Default for ImageNet but can customize this
        super().__init__() # don't forget the super().__init__()!

        # 3. Make the image size is divisble by the patch size
        assert img_size % patch_size == 0, f"Image size must be divisible by patch size, image size: {img_size}, patch size: {patch_size}."

        # 4. Calculate number of patches (height * width/patch^2)
        self.num_patches = (img_size * img_size) // patch_size**2

        # 5. Create learnable class embedding (needs to go at front of sequence of patch embeddings)
        self.class_embedding = nn.Parameter(data=torch.randn(1, 1, embedding_dim),
                                            requires_grad=True)

        # 6. Create learnable position embedding
        self.position_embedding = nn.Parameter(data=torch.randn(1, self.num_patches+1, embedding_dim),
                                               requires_grad=True)
         # 7. Create embedding dropout value
        self.embedding_dropout = nn.Dropout(p=embedding_dropout)

        # 8. Create patch embedding layer
        self.patch_embedding = PatchEmbedding(in_channels=in_channels,
                                              patch_size=patch_size,
                                              embedding_dim=embedding_dim)

        # 9. Create Transformer Encoder blocks (we can stack Transformer Encoder blocks using nn.Sequential())
        # Note: The "*" means "all"
        self.transformer_encoder = nn.Sequential(*[TransformerEncoderBlock(embedding_dim=embedding_dim,
                                                                            num_heads=num_heads,
                                                                            mlp_size=mlp_size,
                                                                            mlp_dropout=mlp_dropout) for _ in range(num_transformer_layers)])

        # 10. Create classifier head
        self.classifier = nn.Sequential(
            nn.LayerNorm(normalized_shape=embedding_dim),
            nn.Linear(in_features=embedding_dim,
                      out_features=num_classes)
        )

    # 11. Create a forward() method
    def forward(self, x):

        # 12. Get batch size
        batch_size = x.shape[0]

        # 13. Create class token embedding and expand it to match the batch size (equation 1)
        class_token = self.class_embedding.expand(batch_size, -1, -1) # "-1" means to infer the dimension (try this line on its own)
         # 14. Create patch embedding (equation 1)
        x = self.patch_embedding(x)

        # 15. Concat class embedding and patch embedding (equation 1)
        x = torch.cat((class_token, x), dim=1)

        # 16. Add position embedding to patch embedding (equation 1)
        x = self.position_embedding + x

        # 17. Run embedding dropout (Appendix B.1)
        x = self.embedding_dropout(x)

        # 18. Pass patch, position and class embedding through transformer encoder layers (equations 2 & 3)
        x = self.transformer_encoder(x)

        # 19. Put 0 index logit through classifier (equation 4)
        x = self.classifier(x[:, 0]) # run on each sample in a batch at 0 index

        return x

# %%
import torch

from tqdm.auto import tqdm
from typing import Dict, List, Tuple

def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               device: torch.device) -> Tuple[float, float]:
    """Trains a PyTorch model for a single epoch.

    Turns a target PyTorch model to training mode and then
    runs through all of the required training steps (forward
    pass, loss calculation, optimizer step).

    Args:
    model: A PyTorch model to be trained.
    dataloader: A DataLoader instance for the model to be trained on.
    loss_fn: A PyTorch loss function to minimize.
    optimizer: A PyTorch optimizer to help minimize the loss function.
    device: A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
    A tuple of training loss and training accuracy metrics.
    In the form (train_loss, train_accuracy). For example:

    (0.1112, 0.8743)
    """
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metric across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              device: torch.device) -> Tuple[float, float]:
    """Tests a PyTorch model for a single epoch.

    Turns a target PyTorch model to "eval" mode and then performs
    a forward pass on a testing dataset.

    Args:
    model: A PyTorch model to be tested.
    dataloader: A DataLoader instance for the model to be tested on.
    loss_fn: A PyTorch loss function to calculate loss on the test data.
    device: A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
    A tuple of testing loss and testing accuracy metrics.
    In the form (test_loss, test_accuracy). For example:

    (0.0223, 0.8985)
    """
    # Put model in eval mode
    model.eval()

    # Setup test loss and test accuracy values
    test_loss, test_acc = 0, 0

    # Turn on inference context manager
    with torch.inference_mode():
        # Loop through DataLoader batches
        for batch, (X, y) in enumerate(dataloader):
            # Send data to target device
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred_logits = model(X)

            # 2. Calculate and accumulate loss
            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            # Calculate and accumulate accuracy
            test_pred_labels = test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

    # Adjust metrics to get average loss and accuracy per batch
    test_loss = test_loss / len(dataloader)
    test_acc = test_acc / len(dataloader)
    return test_loss, test_acc

def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          device: torch.device) -> Dict[str, List]:
    """Trains and tests a PyTorch model.

    Passes a target PyTorch models through train_step() and test_step()
    functions for a number of epochs, training and testing the model
    in the same epoch loop.

    Calculates, prints and stores evaluation metrics throughout.

    Args:
    model: A PyTorch model to be trained and tested.
    train_dataloader: A DataLoader instance for the model to be trained on.
    test_dataloader: A DataLoader instance for the model to be tested on.
    optimizer: A PyTorch optimizer to help minimize the loss function.
    loss_fn: A PyTorch loss function to calculate loss on both datasets.
    epochs: An integer indicating how many epochs to train for.
    device: A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
    A dictionary of training and testing loss as well as training and
    testing accuracy metrics. Each metric has a value in a list for
    each epoch.
    In the form: {train_loss: [...],
              train_acc: [...],
              test_loss: [...],
              test_acc: [...]}
    For example if training for epochs=2:
             {train_loss: [2.0616, 1.0537],
              train_acc: [0.3945, 0.3945],
              test_loss: [1.2641, 1.5706],
              test_acc: [0.3400, 0.2973]}
    """
    # Create empty results dictionary
    results = {"train_loss": [],
               "train_acc": [],
               "test_loss": [],
               "test_acc": []
    }

    # Make sure model on target device
    model.to(device)

    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                          dataloader=train_dataloader,
                                          loss_fn=loss_fn,
                                          optimizer=optimizer,
                                          device=device)
        test_loss, test_acc = test_step(model=model,
          dataloader=test_dataloader,
          loss_fn=loss_fn,
          device=device)

        # Print out what's happening
        print(
          f"Epoch: {epoch+1} | "
          f"train_loss: {train_loss:.4f} | "
          f"train_acc: {train_acc:.4f} | "
          f"test_loss: {test_loss:.4f} | "
          f"test_acc: {test_acc:.4f}"
        )

        # Update results dictionary
        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)

    # Return the filled results at the end of the epochs
    return results

# %%
# Train our MOdel

# Create an instance of ViT with the number of classes we're working with (pizza, steak, sushi)
vit = ViT(num_classes=len(class_names))
#from going_modular.going_modular import engine

# Setup the optimizer to optimize our ViT model parameters using hyperparameters from the ViT paper
optimizer = torch.optim.Adam(params=vit.parameters(),
                             lr=3e-3, # Base LR from Table 3 for ViT-* ImageNet-1k
                             betas=(0.9, 0.999), # default values but also mentioned in ViT paper section 4.1 (Training & Fine-tuning)
                             weight_decay=0.3) # from the ViT paper section 4.1 (Training & Fine-tuning) and Table 3 for ViT-* ImageNet-1k

# Setup the loss function for multi-class classification
loss_fn = torch.nn.CrossEntropyLoss()

# Set the seeds
set_seeds()

# Train the model and save the training results to a dictionary
results = train(model=vit,
                       train_dataloader=train_dataloader,
                       test_dataloader=test_dataloader,
                       optimizer=optimizer,
                       loss_fn=loss_fn,
                       epochs=8,
                       device=device)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.0471 | train_acc: 0.1729 | test_loss: 1.9698 | test_acc: 0.1868
# Epoch: 2 | train_loss: 1.9276 | train_acc: 0.1704 | test_loss: 1.9037 | test_acc: 0.1868
# Epoch: 3 | train_loss: 1.9163 | train_acc: 0.1753 | test_loss: 1.9145 | test_acc: 0.1624
# Epoch: 4 | train_loss: 1.9207 | train_acc: 0.1810 | test_loss: 1.9155 | test_acc: 0.1624
# Epoch: 5 | train_loss: nan | train_acc: 0.1888 | test_loss: nan | test_acc: 0.1624
# Epoch: 6 | train_loss: nan | train_acc: 0.1843 | test_loss: nan | test_acc: 0.1624
# Epoch: 7 | train_loss: nan | train_acc: 0.1843 | test_loss: nan | test_acc: 0.1624
# Epoch: 8 | train_loss: nan | train_acc: 0.1843 | test_loss: nan | test_acc: 0.1624

# %%
# To check out our ViT model's loss curves, we can use the plot_loss_curves function from helper_functions.py
#from helper_functions import plot_loss_curves

# Plot our ViT model's loss curves
#plot_loss_curves(results)

# %%
import torch
import torchvision
from torchvision import transforms
import matplotlib.pyplot as plt
import cv2
from typing import List, Tuple

from PIL import Image
# Set device
device = "cuda" if torch.cuda.is_available() else "cpu"

# Predict on a target image with a target model
# Function created in: https://www.learnpytorch.io/06_pytorch_transfer_learning/#6-make-predictions-on-images-from-the-test-set
def pred_and_plot_image(
    model: torch.nn.Module,
    class_names: List[str],
    image_path: str,
    image_size: Tuple[int, int] = (224, 224),
    transform: torchvision.transforms = None,
    device: torch.device = device,
):
    """Predicts on a target image with a target model.

    Args:
        model (torch.nn.Module): A trained (or untrained) PyTorch model to predict on an image.
        class_names (List[str]): A list of target classes to map predictions to.
        image_path (str): Filepath to target image to predict on.
        image_size (Tuple[int, int], optional): Size to transform target image to. Defaults to (224, 224).
        transform (torchvision.transforms, optional): Transform to perform on image. Defaults to None which uses ImageNet normalization.
        device (torch.device, optional): Target device to perform prediction on. Defaults to device.
    """

    # Open image
    # Open image and check for grayscale
   # img = cv2.imread(image_path)
    #if len(img.shape) == 2 or img.shape[2] == 1:  # Grayscale check
     #   img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)  # Convert to RGB
    img = Image.open(image_path)
    # Convert grayscale to RGB if needed
    if len(img.getbands()) == 1:  # Check for grayscale
        img = img.convert('RGB')

    # Create transformation for image (if one doesn't exist)
    if transform is not None:
        image_transform = transform
    else:
        image_transform = transforms.Compose(
            [
                transforms.Resize(image_size),
                transforms.ToTensor(),
                transforms.Normalize(
                    mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]
                ),
            ]
        )

    ### Predict on image ###

    # Make sure the model is on the target device
    model.to(device)

    # Turn on model evaluation mode and inference mode
    model.eval()
    with torch.inference_mode():
        # Transform and add an extra dimension to image (model requires samples in [batch_size, color_channels, height, width])
        transformed_image = image_transform(img).unsqueeze(dim=0)

        # Make a prediction on image with an extra dimension and send it to the target device
        target_image_pred = model(transformed_image.to(device))

    # Convert logits -> prediction probabilities (using torch.softmax() for multi-class classification)
    target_image_pred_probs = torch.softmax(target_image_pred, dim=1)

    # Convert prediction probabilities -> prediction labels
    target_image_pred_label = torch.argmax(target_image_pred_probs, dim=1)

    # Plot image with predicted label and probability
    plt.figure()
    plt.imshow(img)
    plt.title(
        f"Pred: {class_names[target_image_pred_label]} | Prob: {target_image_pred_probs.max():.3f}"
    )
    plt.axis(False)

# %%
import requests
import numpy as np

# Import function to make predictions on images and plot them
#from going_modular.going_modular.predictions import pred_and_plot_image

import cv2

# Predict on custom image
pred_and_plot_image(model=vit,
                    image_path=input_image,
                    class_names=class_names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3230     try:
# -> 3231         fp.seek(0)
#    3232     except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-5ae96ad7c2fc> in <cell line: 27>()
#      25
#      26 # Predict on custom image
# ---> 27 pred_and_plot_image(model=vit,
#      28                     image_path=input_image,
#      29                     class_names=class_names)
#
# <ipython-input-29-d09b3dbc7300> in pred_and_plot_image(model, class_names, image_path, image_size, transform, device)
#      32
#      33     # Open image
# ---> 34     img = Image.open(image_path)
#      35
#      36     # Create transformation for image (if one doesn't exist)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3231         fp.seek(0)
#    3232     except (AttributeError, io.UnsupportedOperation):
# -> 3233         fp = io.BytesIO(fp.read())
#    3234         exclusive_fp = True
#    3235
#
# AttributeError: 'numpy.ndarray' object has no attribute 'read'

# %%
import matplotlib.pyplot as plt
import torch
import torchvision

from torch import nn
from torchvision import transforms
#from helper_functions import set_seeds

# %%
import torch

def set_seeds(seed: int=42):
    """Sets random sets for torch operations.

    Args:
        seed (int, optional): Random seed to set. Defaults to 42.
    """
    # Set the seed for general torch operations
    torch.manual_seed(seed)
    # Set the seed for CUDA torch operations (ones that happen on the GPU)
    torch.cuda.manual_seed(seed)

# %%
# 1. Get pretrained weights for ViT-Base
pretrained_vit_weights = torchvision.models.ViT_B_16_Weights.DEFAULT

# 2. Setup a ViT model instance with pretrained weights
pretrained_vit = torchvision.models.vit_b_16(weights=pretrained_vit_weights).to(device)

# 3. Freeze the base parameters
for parameter in pretrained_vit.parameters():
    parameter.requires_grad = False

# 4. Change the classifier head
class_names = ['angry','disgust','fear','happy','neutral','sad','surprise']

set_seeds()
pretrained_vit.heads = nn.Linear(in_features=768, out_features=len(class_names)).to(device)
# pretrained_vit # uncomment for model output
# Out:
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [00:02<00:00, 152MB/s]

# %%
# !pip install torchinfo
from torchinfo import summary

# Print a summary using torchinfo (uncomment for actual output)
summary(model=pretrained_vit,
        input_size=(32, 3, 224, 224), # (batch_size, color_channels, height, width)
        # col_names=["input_size"], # uncomment for smaller output
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.10/dist-packages (1.8.0)
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# VisionTransformer (VisionTransformer)                        [32, 3, 224, 224]    [32, 7]              768                  Partial
# ├─Conv2d (conv_proj)                                         [32, 3, 224, 224]    [32, 768, 14, 14]    (590,592)            False
# ├─Encoder (encoder)                                          [32, 197, 768]       [32, 197, 768]       151,296              False
# │    └─Dropout (dropout)                                     [32, 197, 768]       [32, 197, 768]       --                   --
# │    └─Sequential (layers)                                   [32, 197, 768]       [32, 197, 768]       --                   False
# │    │    └─EncoderBlock (encoder_layer_0)                   [32, 197, 768]       [32, 197, 768]       (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_1)                   [32, 197, 768]       [32, 197, 768]       (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_2)                   [32, 197, 768]       [32, 197, 768]       (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_3)                   [32, 197, 768]       [32, 197, 768]       (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_4)                   [32, 197, 768]       [32, 197, 768]       (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_5)                   [32, 197, 768]       [32, 197, 768]       (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_6)                   [32, 197, 768]       [32, 197, 768]       (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_7)                   [32, 197, 768]       [32, 197, 768]       (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_8)                   [32, 197, 768]       [32, 197, 768]       (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_9)                   [32, 197, 768]       [32, 197, 768]       (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_10)                  [32, 197, 768]       [32, 197, 768]       (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_11)                  [32, 197, 768]       [32, 197, 768]       (7,087,872)          False
# │    └─LayerNorm (ln)                                        [32, 197, 768]       [32, 197, 768]       (1,536)              False
# ├─Linear (heads)                                             [32, 768]            [32, 7]              5,383                True
# ============================================================================================================================================
# Total params: 85,804,039
# Trainable params: 5,383
# Non-trainable params: 85,798,656
# Total mult-adds (G): 5.52
# ============================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 3330.74
# Params size (MB): 229.21
# Estimated Total Size (MB): 3579.22
# ============================================================================================================================================

# %%
# Get automatic transforms from pretrained ViT weights
pretrained_vit_transforms = pretrained_vit_weights.transforms()
print(pretrained_vit_transforms)
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %%
import os

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

NUM_WORKERS = os.cpu_count()

def create_dataloaders(
    train_dir: str,
    test_dir: str,
    transform: transforms.Compose,
    batch_size: int,
    num_workers: int=NUM_WORKERS
):

  # Use ImageFolder to create dataset(s)
  train_data = datasets.ImageFolder(train_dir, transform=transform)
  test_data = datasets.ImageFolder(test_dir, transform=transform)

  # Get class names
  class_names = train_data.classes

  # Turn images into data loaders
  train_dataloader = DataLoader(
      train_data,
      batch_size=batch_size,
      shuffle=True,
      num_workers=num_workers,
      pin_memory=True,
  )
  test_dataloader = DataLoader(
      test_data,
      batch_size=batch_size,
      shuffle=False,
      num_workers=num_workers,
      pin_memory=True,
  )

  return train_dataloader, test_dataloader, class_names

# %%
# Setup dataloaders
train_dataloader_pretrained, test_dataloader_pretrained, class_names = create_dataloaders(train_dir=train_dir,
                                                                                                     test_dir=test_dir,
                                                                                                     transform=pretrained_vit_transforms,
                                                                                                     batch_size=32) # Could increa

# %%
# Create optimizer and loss function
optimizer = torch.optim.Adam(params=pretrained_vit.parameters(),
                             lr=1e-3)
loss_fn = torch.nn.CrossEntropyLoss()

# Train the classifier head of the pretrained ViT feature extractor model
set_seeds()
pretrained_vit_results = train(model=pretrained_vit,
                                      train_dataloader=train_dataloader_pretrained,
                                      test_dataloader=test_dataloader_pretrained,
                                      optimizer=optimizer,
                                      loss_fn=loss_fn,
                                      epochs=10,
                                      device=device)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.6173 | train_acc: 0.3653 | test_loss: 1.4852 | test_acc: 0.4407
# Epoch: 2 | train_loss: 1.4436 | train_acc: 0.4547 | test_loss: 1.4203 | test_acc: 0.4682
# Epoch: 3 | train_loss: 1.3713 | train_acc: 0.4889 | test_loss: 1.3785 | test_acc: 0.4757
# Epoch: 4 | train_loss: 1.3295 | train_acc: 0.4993 | test_loss: 1.3980 | test_acc: 0.4700
# Epoch: 5 | train_loss: 1.2921 | train_acc: 0.5185 | test_loss: 1.3754 | test_acc: 0.4754
# Epoch: 6 | train_loss: 1.2616 | train_acc: 0.5352 | test_loss: 1.3481 | test_acc: 0.4921
# Epoch: 7 | train_loss: 1.2475 | train_acc: 0.5386 | test_loss: 1.3850 | test_acc: 0.4794
# Epoch: 8 | train_loss: 1.2313 | train_acc: 0.5409 | test_loss: 1.3476 | test_acc: 0.4988
# Epoch: 9 | train_loss: 1.2226 | train_acc: 0.5451 | test_loss: 1.3623 | test_acc: 0.4924
# Epoch: 10 | train_loss: 1.1964 | train_acc: 0.5583 | test_loss: 1.3389 | test_acc: 0.4985

# %%
# Setup custom image path
custom_image_path = "/content/fer2013/test/sad/PublicTest_20957094.jpg"

# Predict on custom image
pred_and_plot_image(model=pretrained_vit,
                    image_path=custom_image_path,
                    class_names=class_names)

# %%
# Setup custom image path
custom_image_path = "/content/fer2013/test/surprise/PublicTest_15746138.jpg"

# Predict on custom image
pred_and_plot_image(model=pretrained_vit,
                    image_path=custom_image_path,
                    class_names=class_names)
